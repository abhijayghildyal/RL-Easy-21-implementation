# %% [markdown]
# ## Monte Carlo Implementation for Easy 21
#
# Links
# Lecture series : http://www0.cs.ucl.ac.uk/staff/d.silver/web/Teaching.html
# Assignment : http://www0.cs.ucl.ac.uk/staff/d.silver/web/Teaching_files/Easy21-Johannes.pdf

# %%
import numpy as np
from scipy import stats
import random
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %%
xk = np.arange(2)
pk = [1/float(3),2/float(3)]
CUSTOM_RANDOMIZE = stats.rv_discrete(values=(xk,pk))
CARD_COLOR = ['red','black']

# %%
def deal():
    # 0 is red and 1 is black
    cardColorIndex = CUSTOM_RANDOMIZE.rvs(size=1)
    return cardColorIndex, random.randint(1, 10)

# %%
def step(state,action):
    # state[0]- dealer's first card and state[1]- player's sum
    playerSum = state[1]
    dealerSum = state[0]
    
    if action == 0:
        # player action = stick
        print "stick: ",playerSum
        # dealer plays
        dealerSum = dealerPlaying(state[0])
        if dealerSum >21:
            return [dealerSum,playerSum],1
        elif dealerSum < playerSum:
            return [dealerSum,playerSum],1
        elif dealerSum == playerSum:
            return [dealerSum,playerSum],0
        elif dealerSum > playerSum:
            return [dealerSum,playerSum],-1  
    else:
        # player action = hit
        cardColorIndex, cardNumber = deal()
        #print cardColorIndex,cardNumber
        if cardColorIndex == 0:
            # subtract from sum
            playerSum-= cardNumber
        else:
            # add to sum
            playerSum += cardNumber
            
        if playerSum < 21 and playerSum > 1:
            return [dealerSum,playerSum],0
        else:
            return [dealerSum,playerSum],-1

# %%
def dealerPlaying(dealerSum):
    
    while(dealerSum < 17 and dealerSum>=1 ):
        cardColorIndex, cardNumber = deal()
        #print dealerSum
        if cardColorIndex == 0:
            # subtract from sum
            dealerSum-= cardNumber
        else:
            # add to sum
            dealerSum+= cardNumber
    return dealerSum

# %%
dealerPlaying(15)
# Out:
# 18

# %%
step([7,19],0)
# Out:
# stick:  19
# ([21, 19], -1)

# %%
def monteCarlo():
    q = np.zeros(21*10*2).reshape(10,21,2)
    n = np.zeros(21*10*2).reshape(10,21,2)
    
    for i in xrange(10000):
        dealerSumArr = []
        playerSumArr = []
        
        # Both of them draw a black card
        
        dealerSumArr.append(random.randint(1, 10))
        playerSumArr.append(random.randint(1, 10))
        
        ## play mofo
        reward=0
        while (reward==0):
            # next action random
            action = random.randint(0,1)
            
            dealerAndPlayerSum , reward = step( [dealerSumArr[0],playerSumArr[len(playerSumArr)-1]] ,action)
            
            n[ dealerSumArr[0]-1, playerSumArr[len(playerSumArr)-1]-1, action]+=1
            
            if reward == 0:
                playerSumArr.append(dealerAndPlayerSum[1])            
            if action==0:
                dealerSumArr.append(dealerAndPlayerSum[0])
        
        print i," -- ",dealerSumArr,playerSumArr,dealerAndPlayerSum[1],reward
        
        print "dealer: ",dealerSumArr[0], \
        "playerSum: ",playerSumArr[-1], \
        "action: ",action, \
        "n: ",n[ dealerSumArr[0]-1, playerSumArr[-1]-1, action]
        
        # Bellman equation
        value = q[ dealerSumArr[0]-1, playerSumArr[ -1]-1, action ] = \
        q[ dealerSumArr[0]-1, playerSumArr[len(playerSumArr)-1]-1, action] \
            + (1/n[ dealerSumArr[0]-1, playerSumArr[-1]-1, action])\
            *(reward- q[ dealerSumArr[0]-1, playerSumArr[-1]-1, action] )
            
        for playerSum in reversed(playerSumArr[:-1]):
            q[ dealerSumArr[0]-1, playerSum-1, 1] = value
    return q,n

# %%
#a =np.zeros(21*10*2).reshape(10,21,2)
#a[0,0,0]=1
#a[0,0][1]=2

# %%
q,n = monteCarlo()
# Out:
# stick:  16
# 0  --  [1, -5] [7, 16] 16 1
# dealer:  1 playerSum:  16 action:  0 n:  1.0
# 1  --  [6] [7] 0 -1
# dealer:  6 playerSum:  7 action:  1 n:  1.0
# stick:  12
# 2  --  [10, -6] [8, 12] 12 1
# dealer:  10 playerSum:  12 action:  0 n:  1.0
# stick:  16
# 3  --  [8, 19] [8, 10, 16] 16 -1
# dealer:  8 playerSum:  16 action:  0 n:  1.0
# 4  --  [3] [7] 0 -1
# dealer:  3 playerSum:  7 action:  1 n:  1.0
# 5  --  [9] [5] 1 -1
# dealer:  9 playerSum:  5 action:  1 n:  1.0
# stick:  8
# 6  --  [4, 20] [5, 15, 11, 8] 8 -1
# dealer:  4 playerSum:  8 action:  0 n:  1.0
# stick:  10
# 7  --  [8, 0] [1, 7, 10] 10 1
# dealer:  8 playerSum:  10 action:  0 n:  1.0
# 8  --  [9] [3, 13] 21 -1
# dealer:  9 playerSum:  13 action:  1 n:  1.0
# 9  --  [8] [3] -1 -1
# dealer:  8 playerSum:  3 action:  1 n:  1.0
# 10  --  [9] [5, 13] 22 -1
# dealer:  9 playerSum:  13 action:  1 n:  2.0
# stick:  6
# 11  --  [5, 0] [9, 6] 6 1
# dealer:  5 playerSum:  6 action:  0 n:  1.0
# stick:  1
# 12  --  [9, -1] [1] 1 1
# dealer:  9 playerSum:  1 action:  0 n:  1.0
# stick:  4
# 13  --  [1, 19] [4] 4 -1
# dealer:  1 playerSum:  4 action:  0 n:  1.0
# 14  --  [9] [4] -3 -1
# dealer:  9 playerSum:  4 action:  1 n:  1.0
# stick:  4
# 15  --  [10, 25] [4] 4 1
# dealer:  10 playerSum:  4 action:  0 n:  1.0
# stick:  5
# 16  --  [5, 23] [5] 5 1
# dealer:  5 playerSum:  5 action:  0 n:  1.0
# stick:  8
# 17  --  [10, 20] [8] 8 -1
# dealer:  10 playerSum:  8 action:  0 n:  1.0
# stick:  3
# 18  --  [4, -1] [3] 3 1
# dealer:  4 playerSum:  3 action:  0 n:  1.0
# stick:  6
# 19  --  [6, 23] [6] 6 1
# dealer:  6 playerSum:  6 action:  0 n:  1.0
# stick:  3
# 20  --  [6, 19] [3] 3 -1
# dealer:  6 playerSum:  3 action:  0 n:  1.0
# stick:  5
# 21  --  [7, 21] [5] 5 -1
# dealer:  7 playerSum:  5 action:  0 n:  1.0
# stick:  2
# 22  --  [9, 17] [2, 9, 12, 2] 2 -1
# dealer:  9 playerSum:  2 action:  0 n:  1.0
# 23  --  [8] [2] 1 -1
# dealer:  8 playerSum:  2 action:  1 n:  1.0
# stick:  8
# 24  --  [1, -4] [8] 8 1
# dealer:  1 playerSum:  8 action:  0 n:  1.0
# stick:  1
# 25  --  [5, 23] [1] 1 1
# dealer:  5 playerSum:  1 action:  0 n:  1.0
# stick:  10
# 26  --  [9, 17] [10] 10 -1
# dealer:  9 playerSum:  10 action:  0 n:  1.0
# stick:  8
# 27  --  [4, 20] [8] 8 -1
# dealer:  4 playerSum:  8 action:  0 n:  2.0
# stick:  10
# 28  --  [6, -2] [10] 10 1
# dealer:  6 playerSum:  10 action:  0 n:  1.0
# stick:  10
# 29  --  [4, -3] [10] 10 1
# dealer:  4 playerSum:  10 action:  0 n:  1.0
# stick:  10
# 30  --  [4, 21] [10] 10 -1
# dealer:  4 playerSum:  10 action:  0 n:  2.0
# stick:  6
# 31  --  [8, 0] [3, 6] 6 1
# dealer:  8 playerSum:  6 action:  0 n:  1.0
# 32  --  [5] [3] 0 -1
# dealer:  5 playerSum:  3 action:  1 n:  1.0
# stick:  4
# 33  --  [5, -1] [4] 4 1
# dealer:  5 playerSum:  4 action:  0 n:  1.0
# stick:  4
# 34  --  [2, -1] [2, 4] 4 1
# dealer:  2 playerSum:  4 action:  0 n:  1.0
# stick:  12
# 35  --  [6, 21] [10, 12] 12 -1
# dealer:  6 playerSum:  12 action:  0 n:  1.0
# stick:  5
# 36  --  [6, 19] [5] 5 -1
# dealer:  6 playerSum:  5 action:  0 n:  1.0
# stick:  4
# 37  --  [8, 17] [4] 4 -1
# dealer:  8 playerSum:  4 action:  0 n:  1.0
# stick:  8
# 38  --  [6, 17] [8] 8 -1
# dealer:  6 playerSum:  8 action:  0 n:  1.0
# stick:  3
# 39  --  [10, -1] [3] 3 1
# dealer:  10 playerSum:  3 action:  0 n:  1.0
# stick:  11
# 40  --  [8, 18] [6, 16, 11] 11 -1
# dealer:  8 playerSum:  11 action:  0 n:  1.0
# stick:  4
# 41  --  [5, 23] [4] 4 1
# dealer:  5 playerSum:  4 action:  0 n:  2.0
# stick:  8
# 42  --  [1, -9] [8] 8 1
# dealer:  1 playerSum:  8 action:  0 n:  2.0
# stick:  4
# 43  --  [3, -4] [4] 4 1
# dealer:  3 playerSum:  4 action:  0 n:  1.0
# stick:  1
# 44  --  [5, 25] [1] 1 1
# dealer:  5 playerSum:  1 action:  0 n:  2.0
# stick:  16
# 45  --  [4, 18] [7, 16] 16 -1
# dealer:  4 playerSum:  16 action:  0 n:  1.0
# stick:  8
# 46  --  [6, 22] [8] 8 1
# dealer:  6 playerSum:  8 action:  0 n:  2.0
# 47  --  [5] [3] 1 -1
# dealer:  5 playerSum:  3 action:  1 n:  2.0
# stick:  6
# 48  --  [5, -2] [6] 6 1
# dealer:  5 playerSum:  6 action:  0 n:  2.0
# 49  --  [1] [9, 2, 12, 15] 24 -1
# dealer:  1 playerSum:  15 action:  1 n:  1.0
# stick:  9
# 50  --  [9, 17] [9] 9 -1
# dealer:  9 playerSum:  9 action:  0 n:  1.0
# stick:  12
# 51  --  [7, 17] [2, 12] 12 -1
# dealer:  7 playerSum:  12 action:  0 n:  1.0
# stick:  8
# 52  --  [3, 22] [8] 8 1
# dealer:  3 playerSum:  8 action:  0 n:  1.0
# stick:  4
# 53  --  [8, 17] [4] 4 -1
# dealer:  8 playerSum:  4 action:  0 n:  2.0
# 54  --  [6] [4] -4 -1
# dealer:  6 playerSum:  4 action:  1 n:  1.0
# 55  --  [10] [7, 12, 4] 1 -1
# dealer:  10 playerSum:  4 action:  1 n:  1.0
# stick:  1
# 56  --  [4, -7] [1] 1 1
# dealer:  4 playerSum:  1 action:  0 n:  1.0
# stick:  9
# 57  --  [1, 22] [9] 9 1
# dealer:  1 playerSum:  9 action:  0 n:  1.0
# stick:  8
# 58  --  [5, -4] [8] 8 1
# dealer:  5 playerSum:  8 action:  0 n:  1.0
# 59  --  [4] [6] -1 -1
# dealer:  4 playerSum:  6 action:  1 n:  1.0
# stick:  8
# 60  --  [1, 17] [4, 6, 8] 8 -1
# dealer:  1 playerSum:  8 action:  0 n:  3.0
# stick:  14
# 61  --  [6, -3] [9, 14] 14 1
# dealer:  6 playerSum:  14 action:  0 n:  1.0
# stick:  7
# 62  --  [5, -4] [7] 7 1
# dealer:  5 playerSum:  7 action:  0 n:  1.0
# stick:  9
# 63  --  [1, 23] [9] 9 1
# dealer:  1 playerSum:  9 action:  0 n:  2.0
# stick:  18
# stick:  11
# 64  --  [9, 18, 18] [10, 18, 18, 11] 11 -1
# dealer:  9 playerSum:  11 action:  0 n:  1.0
# stick:  10
# 65  --  [4, 17] [2, 10] 10 -1
# dealer:  4 playerSum:  10 action:  0 n:  3.0
# 66  --  [7] [4] 0 -1
# dealer:  7 playerSum:  4 action:  1 n:  1.0
# 67  --  [4] [4] -1 -1
# dealer:  4 playerSum:  4 action:  1 n:  1.0
# stick:  1
# 68  --  [7, 18] [1] 1 -1
# dealer:  7 playerSum:  1 action:  0 n:  1.0
# 69  --  [4] [4] -2 -1
# dealer:  4 playerSum:  4 action:  1 n:  2.0
# stick:  6
# 70  --  [1, 19] [6] 6 -1
# dealer:  1 playerSum:  6 action:  0 n:  1.0
# stick:  18
# 71  --  [6, 19] [10, 18] 18 -1
# dealer:  6 playerSum:  18 action:  0 n:  1.0
# stick:  5
# 72  --  [9, 21] [5] 5 -1
# dealer:  9 playerSum:  5 action:  0 n:  1.0
# stick:  2
# 73  --  [3, -1] [4, 2] 2 1
# dealer:  3 playerSum:  2 action:  0 n:  1.0
# stick:  10
# 74  --  [1, 0] [8, 18, 13, 14, 10] 10 1
# dealer:  1 playerSum:  10 action:  0 n:  1.0
# stick:  17
# 75  --  [7, 20] [8, 17] 17 -1
# dealer:  7 playerSum:  17 action:  0 n:  1.0
# stick:  3
# 76  --  [1, -1] [1, 3] 3 1
# dealer:  1 playerSum:  3 action:  0 n:  1.0
# stick:  4
# 77  --  [5, 17] [4] 4 -1
# dealer:  5 playerSum:  4 action:  0 n:  3.0
# stick:  6
# 78  --  [1, 19] [6] 6 -1
# dealer:  1 playerSum:  6 action:  0 n:  2.0
# stick:  14
# 79  --  [8, 20] [10, 14] 14 -1
# dealer:  8 playerSum:  14 action:  0 n:  1.0
# stick:  2
# 80  --  [2, 0] [2] 2 1
# dealer:  2 playerSum:  2 action:  0 n:  1.0
# stick:  6
# 81  --  [9, 0] [1, 6] 6 1
# dealer:  9 playerSum:  6 action:  0 n:  1.0
# 82  --  [4] [8, 16] 26 -1
# dealer:  4 playerSum:  16 action:  1 n:  1.0
# stick:  10
# 83  --  [2, 0] [5, 10] 10 1
# dealer:  2 playerSum:  10 action:  0 n:  1.0
# stick:  7
# 84  --  [2, 25] [7] 7 1
# dealer:  2 playerSum:  7 action:  0 n:  1.0
# stick:  7
# 85  --  [7, 0] [7] 7 1
# dealer:  7 playerSum:  7 action:  0 n:  1.0
# stick:  14
# 86  --  [1, 21] [1, 9, 14] 14 -1
# dealer:  1 playerSum:  14 action:  0 n:  1.0
# stick:  3
# 87  --  [4, -4] [3] 3 1
# dealer:  4 playerSum:  3 action:  0 n:  2.0
# stick:  7
# 88  --  [4, 22] [7] 7 1
# dealer:  4 playerSum:  7 action:  0 n:  1.0
# stick:  4
# 89  --  [10, 18] [4] 4 -1
# dealer:  10 playerSum:  4 action:  0 n:  2.0
# stick:  12
# 90  --  [1, 22] [8, 12] 12 1
# dealer:  1 playerSum:  12 action:  0 n:  1.0
# 91  --  [7] [2, 3] 0 -1
# dealer:  7 playerSum:  3 action:  1 n:  1.0
# stick:  8
# 92  --  [5, -6] [8] 8 1
# dealer:  5 playerSum:  8 action:  0 n:  2.0
# stick:  7
# 93  --  [8, 22] [7] 7 1
# dealer:  8 playerSum:  7 action:  0 n:  1.0
# stick:  10
# 94  --  [7, 25] [10] 10 1
# dealer:  7 playerSum:  10 action:  0 n:  1.0
# 95  --  [4] [7] -3 -1
# dealer:  4 playerSum:  7 action:  1 n:  2.0
# stick:  6
# 96  --  [9, 19] [6] 6 -1
# dealer:  9 playerSum:  6 action:  0 n:  2.0
# stick:  15
# 97  --  [1, 22] [6, 14, 15] 15 1
# dealer:  1 playerSum:  15 action:  0 n:  1.0
# stick:  9
# 98  --  [7, 17] [9] 9 -1
# dealer:  7 playerSum:  9 action:  0 n:  1.0
# stick:  2
# 99  --  [2, 0] [9, 11, 12, 2] 2 1
# dealer:  2 playerSum:  2 action:  0 n:  2.0
# stick:  3
# 100  --  [2, -1] [3] 3 1
# dealer:  2 playerSum:  3 action:  0 n:  1.0
# stick:  2
# 101  --  [6, 0] [2] 2 1
# dealer:  6 playerSum:  2 action:  0 n:  1.0
# stick:  1
# 102  --  [6, 22] [1] 1 1
# dealer:  6 playerSum:  1 action:  0 n:  1.0
# stick:  1
# 103  --  [1, -6] [1] 1 1
# dealer:  1 playerSum:  1 action:  0 n:  1.0
# 104  --  [1] [1] -2 -1
# dealer:  1 playerSum:  1 action:  1 n:  3.0
# stick:  2
# 105  --  [4, 17] [2] 2 -1
# dealer:  4 playerSum:  2 action:  0 n:  1.0
# stick:  1
# 106  --  [10, -2] [1] 1 1
# dealer:  10 playerSum:  1 action:  0 n:  1.0
# stick:  2
# 107  --  [1, 23] [2] 2 1
# dealer:  1 playerSum:  2 action:  0 n:  1.0
# stick:  8
# 108  --  [5, 24] [8] 8 1
# dealer:  5 playerSum:  8 action:  0 n:  3.0
# 109  --  [5] [9, 4, 8, 3, 9, 17] 22 -1
# dealer:  5 playerSum:  17 action:  1 n:  1.0
# stick:  10
# 110  --  [10, 24] [10] 10 1
# dealer:  10 playerSum:  10 action:  0 n:  1.0
# 111  --  [6] [1, 4] -3 -1
# dealer:  6 playerSum:  4 action:  1 n:  2.0
# 112  --  [6] [10, 16] 24 -1
# dealer:  6 playerSum:  16 action:  1 n:  1.0
# 113  --  [8] [6, 2] -1 -1
# dealer:  8 playerSum:  2 action:  1 n:  2.0
# 114  --  [6] [5] 1 -1
# dealer:  6 playerSum:  5 action:  1 n:  1.0
# stick:  4
# 115  --  [10, 24] [6, 4] 4 1
# dealer:  10 playerSum:  4 action:  0 n:  3.0
# 116  --  [7] [5, 15, 6, 10] 1 -1
# dealer:  7 playerSum:  10 action:  1 n:  1.0
# stick:  8
# 117  --  [2, -5] [3, 8] 8 1
# dealer:  2 playerSum:  8 action:  0 n:  1.0
# stick:  16
# 118  --  [6, 19] [9, 16] 16 -1
# dealer:  6 playerSum:  16 action:  0 n:  1.0
# stick:  5
# 119  --  [7, 22] [5] 5 1
# dealer:  7 playerSum:  5 action:  0 n:  2.0
# stick:  14
# 120  --  [9, 17] [10, 18, 14] 14 -1
# dealer:  9 playerSum:  14 action:  0 n:  1.0
# stick:  8
# 121  --  [6, 17] [8] 8 -1
# dealer:  6 playerSum:  8 action:  0 n:  3.0
# 122  --  [9] [4] -2 -1
# dealer:  9 playerSum:  4 action:  1 n:  2.0
# stick:  14
# 123  --  [9, 18] [10, 6, 14] 14 -1
# dealer:  9 playerSum:  14 action:  0 n:  2.0
# stick:  4
# 124  --  [8, 23] [2, 4] 4 1
# dealer:  8 playerSum:  4 action:  0 n:  3.0
# stick:  4
# 125  --  [7, 18] [4] 4 -1
# dealer:  7 playerSum:  4 action:  0 n:  1.0
# 126  --  [8] [2] -8 -1
# dealer:  8 playerSum:  2 action:  1 n:  4.0
# stick:  3
# 127  --  [10, 18] [3] 3 -1
# dealer:  10 playerSum:  3 action:  0 n:  2.0
# stick:  10
# 128  --  [1, 17] [10] 10 -1
# dealer:  1 playerSum:  10 action:  0 n:  2.0
# stick:  18
# 129  --  [8, 0] [10, 12, 18] 18 1
# dealer:  8 playerSum:  18 action:  0 n:  1.0
# stick:  10
# 130  --  [6, -6] [3, 10] 10 1
# dealer:  6 playerSum:  10 action:  0 n:  2.0
# stick:  6
# 131  --  [8, 19] [6] 6 -1
# dealer:  8 playerSum:  6 action:  0 n:  2.0
# 132  --  [3] [7, 6, 13, 14] 22 -1
# dealer:  3 playerSum:  14 action:  1 n:  1.0
# stick:  1
# 133  --  [3, 20] [1] 1 -1
# dealer:  3 playerSum:  1 action:  0 n:  1.0
# stick:  10
# 134  --  [7, 21] [10] 10 -1
# dealer:  7 playerSum:  10 action:  0 n:  2.0
# stick:  7
# 135  --  [10, 23] [7] 7 1
# dealer:  10 playerSum:  7 action:  0 n:  1.0
# stick:  4
# 136  --  [2, -1] [4] 4 1
# dealer:  2 playerSum:  4 action:  0 n:  2.0
# stick:  1
# 137  --  [5, 19] [1] 1 -1
# dealer:  5 playerSum:  1 action:  0 n:  3.0
# 138  --  [2] [7] 1 -1
# dealer:  2 playerSum:  7 action:  1 n:  1.0
# stick:  8
# 139  --  [5, 18] [8] 8 -1
# dealer:  5 playerSum:  8 action:  0 n:  4.0
# 140  --  [3] [1, 11, 17] 27 -1
# dealer:  3 playerSum:  17 action:  1 n:  1.0
# stick:  10
# 141  --  [9, 19] [10] 10 -1
# dealer:  9 playerSum:  10 action:  0 n:  2.0
# stick:  8
# 142  --  [3, -4] [8] 8 1
# dealer:  3 playerSum:  8 action:  0 n:  2.0
# stick:  8
# 143  --  [3, -5] [8] 8 1
# dealer:  3 playerSum:  8 action:  0 n:  3.0
# stick:  3
# 144  --  [9, 21] [3] 3 -1
# dealer:  9 playerSum:  3 action:  0 n:  1.0
# stick:  7
# 145  --  [3, -2] [7] 7 1
# dealer:  3 playerSum:  7 action:  0 n:  1.0
# 146  --  [1] [8, 14, 16] 26 -1
# dealer:  1 playerSum:  16 action:  1 n:  1.0
# stick:  2
# 147  --  [7, 17] [2] 2 -1
# dealer:  7 playerSum:  2 action:  0 n:  1.0
# 148  --  [4] [10] 1 -1
# dealer:  4 playerSum:  10 action:  1 n:  1.0
# stick:  10
# 149  --  [1, -6] [9, 10] 10 1
# dealer:  1 playerSum:  10 action:  0 n:  3.0
# stick:  6
# 150  --  [9, -2] [6] 6 1
# dealer:  9 playerSum:  6 action:  0 n:  3.0
# stick:  4
# 151  --  [7, 20] [8, 4] 4 -1
# dealer:  7 playerSum:  4 action:  0 n:  2.0
# stick:  5
# 152  --  [1, 17] [2, 5] 5 -1
# dealer:  1 playerSum:  5 action:  0 n:  1.0
# stick:  6
# 153  --  [6, 22] [6] 6 1
# dealer:  6 playerSum:  6 action:  0 n:  2.0
# stick:  10
# 154  --  [4, 20] [10] 10 -1
# dealer:  4 playerSum:  10 action:  0 n:  4.0
# stick:  9
# 155  --  [2, -3] [9] 9 1
# dealer:  2 playerSum:  9 action:  0 n:  1.0
# stick:  5
# 156  --  [5, -5] [10, 14, 10, 5] 5 1
# dealer:  5 playerSum:  5 action:  0 n:  2.0
# 157  --  [1] [4] -5 -1
# dealer:  1 playerSum:  4 action:  1 n:  2.0
# stick:  14
# 158  --  [5, -1] [8, 14] 14 1
# dealer:  5 playerSum:  14 action:  0 n:  1.0
# stick:  7
# 159  --  [1, 17] [7] 7 -1
# dealer:  1 playerSum:  7 action:  0 n:  1.0
# stick:  10
# 160  --  [10, 24] [10] 10 1
# dealer:  10 playerSum:  10 action:  0 n:  2.0
# stick:  16
# 161  --  [6, 20] [8, 12, 13, 18, 16] 16 -1
# dealer:  6 playerSum:  16 action:  0 n:  2.0
# stick:  5
# 162  --  [2, -1] [5] 5 1
# dealer:  2 playerSum:  5 action:  0 n:  1.0
# stick:  4
# 163  --  [4, -4] [9, 4] 4 1
# dealer:  4 playerSum:  4 action:  0 n:  1.0
# stick:  11
# 164  --  [5, 0] [4, 11] 11 1
# dealer:  5 playerSum:  11 action:  0 n:  1.0
# stick:  8
# 165  --  [7, 19] [8] 8 -1
# dealer:  7 playerSum:  8 action:  0 n:  1.0
# stick:  7
# 166  --  [6, 23] [5, 7] 7 1
# dealer:  6 playerSum:  7 action:  0 n:  1.0
# stick:  12
# 167  --  [3, 25] [3, 7, 12] 12 1
# dealer:  3 playerSum:  12 action:  0 n:  1.0
# stick:  9
# 168  --  [6, 18] [4, 9] 9 -1
# dealer:  6 playerSum:  9 action:  0 n:  1.0
# stick:  11
# 169  --  [2, -1] [3, 11] 11 1
# dealer:  2 playerSum:  11 action:  0 n:  1.0
# stick:  3
# 170  --  [2, -5] [3] 3 1
# dealer:  2 playerSum:  3 action:  0 n:  2.0
# 171  --  [2] [6, 7, 17] 23 -1
# dealer:  2 playerSum:  17 action:  1 n:  1.0
# stick:  12
# 172  --  [10, 25] [6, 12] 12 1
# dealer:  10 playerSum:  12 action:  0 n:  2.0
# stick:  11
# 173  --  [2, -7] [8, 11] 11 1
# dealer:  2 playerSum:  11 action:  0 n:  2.0
# stick:  9
# 174  --  [9, 17] [8, 7, 9] 9 -1
# dealer:  9 playerSum:  9 action:  0 n:  2.0
# stick:  10
# 175  --  [6, 17] [10] 10 -1
# dealer:  6 playerSum:  10 action:  0 n:  3.0
# stick:  2
# 176  --  [5, -8] [2] 2 1
# dealer:  5 playerSum:  2 action:  0 n:  1.0
# stick:  5
# 177  --  [1, -1] [5] 5 1
# dealer:  1 playerSum:  5 action:  0 n:  2.0
# stick:  9
# 178  --  [3, 22] [9] 9 1
# dealer:  3 playerSum:  9 action:  0 n:  1.0
# stick:  7
# 179  --  [5, 25] [9, 7] 7 1
# dealer:  5 playerSum:  7 action:  0 n:  2.0
# stick:  11
# 180  --  [3, 20] [9, 10, 11] 11 -1
# dealer:  3 playerSum:  11 action:  0 n:  1.0
# stick:  10
# 181  --  [5, 17] [3, 10] 10 -1
# dealer:  5 playerSum:  10 action:  0 n:  1.0
# stick:  10
# 182  --  [10, -1] [10] 10 1
# dealer:  10 playerSum:  10 action:  0 n:  3.0
# stick:  2
# 183  --  [8, -4] [2] 2 1
# dealer:  8 playerSum:  2 action:  0 n:  1.0
# stick:  5
# 184  --  [3, -4] [5] 5 1
# dealer:  3 playerSum:  5 action:  0 n:  1.0
# stick:  3
# 185  --  [2, -3] [3] 3 1
# dealer:  2 playerSum:  3 action:  0 n:  3.0
# 186  --  [6] [8] 0 -1
# dealer:  6 playerSum:  8 action:  1 n:  2.0
# 187  --  [9] [2, 5, 11] 21 -1
# dealer:  9 playerSum:  11 action:  1 n:  1.0
# stick:  10
# 188  --  [7, -3] [10] 10 1
# dealer:  7 playerSum:  10 action:  0 n:  3.0
# stick:  7
# 189  --  [2, -3] [7] 7 1
# dealer:  2 playerSum:  7 action:  0 n:  2.0
# 190  --  [4] [7, 11, 2] -4 -1
# dealer:  4 playerSum:  2 action:  1 n:  2.0
# stick:  8
# 191  --  [10, 20] [2, 8] 8 -1
# dealer:  10 playerSum:  8 action:  0 n:  2.0
# 192  --  [6] [1, 3] -2 -1
# dealer:  6 playerSum:  3 action:  1 n:  2.0
# stick:  10
# 193  --  [5, -7] [10] 10 1
# dealer:  5 playerSum:  10 action:  0 n:  2.0
# stick:  6
# 194  --  [2, -5] [6] 6 1
# dealer:  2 playerSum:  6 action:  0 n:  1.0
# stick:  8
# 195  --  [3, -2] [9, 8] 8 1
# dealer:  3 playerSum:  8 action:  0 n:  4.0
# stick:  19
# 196  --  [8, -4] [6, 15, 19] 19 1
# dealer:  8 playerSum:  19 action:  0 n:  1.0
# stick:  5
# 197  --  [8, 19] [5] 5 -1
# dealer:  8 playerSum:  5 action:  0 n:  1.0
# 198  --  [10] [5] 0 -1
# dealer:  10 playerSum:  5 action:  1 n:  1.0
# stick:  4
# 199  --  [10, -8] [4] 4 1
# dealer:  10 playerSum:  4 action:  0 n:  4.0
# stick:  10
# 200  --  [6, 20] [8, 10] 10 -1
# dealer:  6 playerSum:  10 action:  0 n:  4.0
# stick:  8
# 201  --  [3, 0] [10, 8] 8 1
# dealer:  3 playerSum:  8 action:  0 n:  5.0
# stick:  16
# 202  --  [6, -3] [6, 15, 16] 16 1
# dealer:  6 playerSum:  16 action:  0 n:  3.0
# stick:  20
# 203  --  [6, 23] [6, 13, 16, 19, 20] 20 1
# dealer:  6 playerSum:  20 action:  0 n:  1.0
# stick:  9
# 204  --  [5, -5] [9] 9 1
# dealer:  5 playerSum:  9 action:  0 n:  1.0
# stick:  9
# 205  --  [1, -6] [9, 11, 9] 9 1
# dealer:  1 playerSum:  9 action:  0 n:  3.0
# stick:  8
# 206  --  [10, 17] [8] 8 -1
# dealer:  10 playerSum:  8 action:  0 n:  3.0
# stick:  11
# 207  --  [9, 18] [2, 8, 16, 11] 11 -1
# dealer:  9 playerSum:  11 action:  0 n:  2.0
# 208  --  [8] [2, 5] 1 -1
# dealer:  8 playerSum:  5 action:  1 n:  1.0
# stick:  8
# 209  --  [5, 26] [8] 8 1
# dealer:  5 playerSum:  8 action:  0 n:  5.0
# stick:  11
# 210  --  [1, 21] [10, 16, 11] 11 -1
# dealer:  1 playerSum:  11 action:  0 n:  1.0
# stick:  17
# 211  --  [3, 19] [5, 15, 17] 17 -1
# dealer:  3 playerSum:  17 action:  0 n:  1.0
# 212  --  [8] [2] -6 -1
# dealer:  8 playerSum:  2 action:  1 n:  6.0
# stick:  5
# 213  --  [4, 19] [5] 5 -1
# dealer:  4 playerSum:  5 action:  0 n:  1.0
# stick:  9
# 214  --  [1, 18] [9] 9 -1
# dealer:  1 playerSum:  9 action:  0 n:  4.0
# 215  --  [7] [8] -1 -1
# dealer:  7 playerSum:  8 action:  1 n:  3.0
# stick:  3
# 216  --  [1, 22] [2, 3] 3 1
# dealer:  1 playerSum:  3 action:  0 n:  2.0
# stick:  14
# 217  --  [10, 21] [10, 14] 14 -1
# dealer:  10 playerSum:  14 action:  0 n:  1.0
# stick:  1
# 218  --  [1, 21] [1] 1 -1
# dealer:  1 playerSum:  1 action:  0 n:  2.0
# stick:  2
# 219  --  [5, 21] [6, 2] 2 -1
# dealer:  5 playerSum:  2 action:  0 n:  2.0
# stick:  10
# 220  --  [5, 0] [4, 10] 10 1
# dealer:  5 playerSum:  10 action:  0 n:  3.0
# stick:  11
# 221  --  [7, 0] [10, 20, 11] 11 1
# dealer:  7 playerSum:  11 action:  0 n:  1.0
# stick:  10
# 222  --  [10, 21] [2, 10] 10 -1
# dealer:  10 playerSum:  10 action:  0 n:  4.0
# 223  --  [3] [2] -7 -1
# dealer:  3 playerSum:  2 action:  1 n:  1.0
# stick:  4
# 224  --  [7, 19] [4] 4 -1
# dealer:  7 playerSum:  4 action:  0 n:  3.0
# 225  --  [10] [1] -5 -1
# dealer:  10 playerSum:  1 action:  1 n:  1.0
# stick:  11
# 226  --  [7, -2] [9, 11] 11 1
# dealer:  7 playerSum:  11 action:  0 n:  2.0
# stick:  9
# 227  --  [1, 0] [7, 9] 9 1
# dealer:  1 playerSum:  9 action:  0 n:  5.0
# stick:  10
# 228  --  [4, -1] [10] 10 1
# dealer:  4 playerSum:  10 action:  0 n:  5.0
# stick:  13
# 229  --  [7, -3] [3, 13] 13 1
# dealer:  7 playerSum:  13 action:  0 n:  1.0
# stick:  2
# 230  --  [3, 18] [2] 2 -1
# dealer:  3 playerSum:  2 action:  0 n:  2.0
# stick:  10
# 231  --  [3, -2] [10, 18, 10] 10 1
# dealer:  3 playerSum:  10 action:  0 n:  1.0
# stick:  3
# 232  --  [3, -4] [3] 3 1
# dealer:  3 playerSum:  3 action:  0 n:  1.0
# stick:  8
# 233  --  [3, -5] [8] 8 1
# dealer:  3 playerSum:  8 action:  0 n:  6.0
# stick:  11
# 234  --  [4, 18] [9, 11] 11 -1
# dealer:  4 playerSum:  11 action:  0 n:  1.0
# stick:  1
# 235  --  [10, 25] [1] 1 1
# dealer:  10 playerSum:  1 action:  0 n:  2.0
# stick:  8
# 236  --  [3, 24] [6, 8] 8 1
# dealer:  3 playerSum:  8 action:  0 n:  7.0
# 237  --  [7] [4] -2 -1
# dealer:  7 playerSum:  4 action:  1 n:  2.0
# stick:  7
# 238  --  [8, -7] [7] 7 1
# dealer:  8 playerSum:  7 action:  0 n:  2.0
# stick:  9
# 239  --  [9, 21] [9] 9 -1
# dealer:  9 playerSum:  9 action:  0 n:  3.0
# 240  --  [5] [1] -3 -1
# dealer:  5 playerSum:  1 action:  1 n:  1.0
# stick:  1
# 241  --  [4, -6] [1] 1 1
# dealer:  4 playerSum:  1 action:  0 n:  2.0
# stick:  13
# 242  --  [3, 21] [7, 13] 13 -1
# dealer:  3 playerSum:  13 action:  0 n:  1.0
# stick:  1
# 243  --  [2, 0] [1] 1 1
# dealer:  2 playerSum:  1 action:  0 n:  1.0
# stick:  4
# 244  --  [8, -4] [4] 4 1
# dealer:  8 playerSum:  4 action:  0 n:  4.0
# stick:  3
# 245  --  [9, -1] [7, 3] 3 1
# dealer:  9 playerSum:  3 action:  0 n:  2.0
# 246  --  [3] [2] -2 -1
# dealer:  3 playerSum:  2 action:  1 n:  2.0
# stick:  10
# 247  --  [9, 18] [10] 10 -1
# dealer:  9 playerSum:  10 action:  0 n:  3.0
# stick:  8
# 248  --  [3, -2] [8] 8 1
# dealer:  3 playerSum:  8 action:  0 n:  8.0
# stick:  4
# 249  --  [10, 21] [4] 4 -1
# dealer:  10 playerSum:  4 action:  0 n:  5.0
# stick:  3
# 250  --  [10, 18] [3] 3 -1
# dealer:  10 playerSum:  3 action:  0 n:  3.0
# stick:  7
# 251  --  [6, 18] [7] 7 -1
# dealer:  6 playerSum:  7 action:  0 n:  2.0
# stick:  4
# 252  --  [1, 17] [4] 4 -1
# dealer:  1 playerSum:  4 action:  0 n:  2.0
# stick:  7
# 253  --  [10, 0] [7] 7 1
# dealer:  10 playerSum:  7 action:  0 n:  2.0
# stick:  5
# 254  --  [7, 19] [5] 5 -1
# dealer:  7 playerSum:  5 action:  0 n:  3.0
# stick:  10
# 255  --  [3, 17] [10] 10 -1
# dealer:  3 playerSum:  10 action:  0 n:  2.0
# stick:  7
# 256  --  [5, 0] [7] 7 1
# dealer:  5 playerSum:  7 action:  0 n:  3.0
# stick:  4
# 257  --  [8, -6] [4] 4 1
# dealer:  8 playerSum:  4 action:  0 n:  5.0
# stick:  17
# 258  --  [9, 18] [7, 11, 17] 17 -1
# dealer:  9 playerSum:  17 action:  0 n:  1.0
# stick:  7
# 259  --  [1, 21] [7] 7 -1
# dealer:  1 playerSum:  7 action:  0 n:  2.0
# stick:  8
# 260  --  [4, 22] [8] 8 1
# dealer:  4 playerSum:  8 action:  0 n:  3.0
# stick:  14
# 261  --  [8, 21] [9, 19, 14] 14 -1
# dealer:  8 playerSum:  14 action:  0 n:  2.0
# stick:  9
# 262  --  [9, 25] [9] 9 1
# dealer:  9 playerSum:  9 action:  0 n:  4.0
# stick:  3
# 263  --  [2, -4] [3] 3 1
# dealer:  2 playerSum:  3 action:  0 n:  4.0
# stick:  8
# 264  --  [6, 0] [8] 8 1
# dealer:  6 playerSum:  8 action:  0 n:  4.0
# stick:  1
# 265  --  [4, -2] [1] 1 1
# dealer:  4 playerSum:  1 action:  0 n:  3.0
# stick:  2
# 266  --  [2, -7] [2] 2 1
# dealer:  2 playerSum:  2 action:  0 n:  3.0
# stick:  7
# 267  --  [4, -8] [7] 7 1
# dealer:  4 playerSum:  7 action:  0 n:  2.0
# 268  --  [9] [2] -3 -1
# dealer:  9 playerSum:  2 action:  1 n:  4.0
# stick:  6
# 269  --  [9, 18] [6, 3, 6] 6 -1
# dealer:  9 playerSum:  6 action:  0 n:  4.0
# stick:  3
# 270  --  [1, 26] [7, 3] 3 1
# dealer:  1 playerSum:  3 action:  0 n:  3.0
# stick:  10
# 271  --  [9, 18] [10] 10 -1
# dealer:  9 playerSum:  10 action:  0 n:  4.0
# stick:  10
# 272  --  [4, -7] [10] 10 1
# dealer:  4 playerSum:  10 action:  0 n:  6.0
# stick:  9
# 273  --  [3, -4] [9] 9 1
# dealer:  3 playerSum:  9 action:  0 n:  2.0
# stick:  7
# 274  --  [10, -2] [7] 7 1
# dealer:  10 playerSum:  7 action:  0 n:  3.0
# stick:  10
# 275  --  [3, 18] [6, 10] 10 -1
# dealer:  3 playerSum:  10 action:  0 n:  3.0
# stick:  9
# 276  --  [1, 19] [3, 9] 9 -1
# dealer:  1 playerSum:  9 action:  0 n:  6.0
# stick:  2
# 277  --  [4, -2] [2] 2 1
# dealer:  4 playerSum:  2 action:  0 n:  2.0
# stick:  5
# 278  --  [4, 24] [3, 5, 11, 20, 10, 5] 5 1
# dealer:  4 playerSum:  5 action:  0 n:  2.0
# stick:  8
# 279  --  [6, 21] [8] 8 -1
# dealer:  6 playerSum:  8 action:  0 n:  5.0
# 280  --  [6] [1] -4 -1
# dealer:  6 playerSum:  1 action:  1 n:  3.0
# stick:  14
# 281  --  [1, 17] [7, 14] 14 -1
# dealer:  1 playerSum:  14 action:  0 n:  2.0
# stick:  19
# 282  --  [1, -3] [6, 14, 19] 19 1
# dealer:  1 playerSum:  19 action:  0 n:  1.0
# stick:  7
# 283  --  [8, 17] [3, 7] 7 -1
# dealer:  8 playerSum:  7 action:  0 n:  3.0
# stick:  5
# 284  --  [7, -2] [5] 5 1
# dealer:  7 playerSum:  5 action:  0 n:  4.0
# stick:  10
# 285  --  [7, 17] [9, 10] 10 -1
# dealer:  7 playerSum:  10 action:  0 n:  4.0
# stick:  3
# 286  --  [2, 19] [3] 3 -1
# dealer:  2 playerSum:  3 action:  0 n:  5.0
# stick:  5
# 287  --  [1, -8] [5] 5 1
# dealer:  1 playerSum:  5 action:  0 n:  3.0
# stick:  4
# 288  --  [7, 20] [4] 4 -1
# dealer:  7 playerSum:  4 action:  0 n:  4.0
# stick:  8
# 289  --  [3, -4] [8] 8 1
# dealer:  3 playerSum:  8 action:  0 n:  9.0
# 290  --  [8] [3, 2] -6 -1
# dealer:  8 playerSum:  2 action:  1 n:  7.0
# 291  --  [2] [1] -7 -1
# dealer:  2 playerSum:  1 action:  1 n:  1.0
# stick:  7
# 292  --  [6, -2] [7] 7 1
# dealer:  6 playerSum:  7 action:  0 n:  3.0
# stick:  6
# 293  --  [5, -4] [6] 6 1
# dealer:  5 playerSum:  6 action:  0 n:  3.0
# 294  --  [1] [7] 0 -1
# dealer:  1 playerSum:  7 action:  1 n:  5.0
# stick:  15
# 295  --  [6, -4] [2, 6, 15] 15 1
# dealer:  6 playerSum:  15 action:  0 n:  1.0
# stick:  7
# 296  --  [10, 24] [7] 7 1
# dealer:  10 playerSum:  7 action:  0 n:  4.0
# stick:  15
# 297  --  [3, -5] [4, 9, 15] 15 1
# dealer:  3 playerSum:  15 action:  0 n:  1.0
# 298  --  [4] [5, 8, 16] 24 -1
# dealer:  4 playerSum:  16 action:  1 n:  2.0
# stick:  11
# 299  --  [3, 18] [9, 11] 11 -1
# dealer:  3 playerSum:  11 action:  0 n:  2.0
# 300  --  [1] [9, 19, 17] 24 -1
# dealer:  1 playerSum:  17 action:  1 n:  1.0
# stick:  9
# 301  --  [1, 19] [9] 9 -1
# dealer:  1 playerSum:  9 action:  0 n:  7.0
# stick:  8
# 302  --  [9, 17] [8] 8 -1
# dealer:  9 playerSum:  8 action:  0 n:  1.0
# stick:  4
# 303  --  [6, 19] [4] 4 -1
# dealer:  6 playerSum:  4 action:  0 n:  1.0
# stick:  5
# 304  --  [5, 19] [5] 5 -1
# dealer:  5 playerSum:  5 action:  0 n:  3.0
# stick:  10
# 305  --  [8, -2] [10] 10 1
# dealer:  8 playerSum:  10 action:  0 n:  2.0
# stick:  4
# 306  --  [6, 19] [4] 4 -1
# dealer:  6 playerSum:  4 action:  0 n:  2.0
# stick:  7
# 307  --  [3, 22] [7] 7 1
# dealer:  3 playerSum:  7 action:  0 n:  2.0
# stick:  10
# 308  --  [6, 18] [4, 5, 10] 10 -1
# dealer:  6 playerSum:  10 action:  0 n:  5.0
# stick:  6
# 309  --  [3, 25] [6] 6 1
# dealer:  3 playerSum:  6 action:  0 n:  1.0
# stick:  5
# 310  --  [8, 21] [5] 5 -1
# dealer:  8 playerSum:  5 action:  0 n:  2.0
# stick:  5
# 311  --  [8, 17] [5] 5 -1
# dealer:  8 playerSum:  5 action:  0 n:  3.0
# stick:  7
# 312  --  [9, 18] [1, 7] 7 -1
# dealer:  9 playerSum:  7 action:  0 n:  1.0
# 313  --  [6] [7] 1 -1
# dealer:  6 playerSum:  7 action:  1 n:  2.0
# 314  --  [3] [3] -5 -1
# dealer:  3 playerSum:  3 action:  1 n:  2.0
# stick:  11
# 315  --  [8, 0] [5, 11, 16, 11] 11 1
# dealer:  8 playerSum:  11 action:  0 n:  2.0
# stick:  5
# 316  --  [2, 21] [5] 5 -1
# dealer:  2 playerSum:  5 action:  0 n:  2.0
# stick:  5
# 317  --  [6, 22] [5] 5 1
# dealer:  6 playerSum:  5 action:  0 n:  2.0
# stick:  9
# 318  --  [7, 17] [9] 9 -1
# dealer:  7 playerSum:  9 action:  0 n:  2.0
# 319  --  [8] [8] 0 -1
# dealer:  8 playerSum:  8 action:  1 n:  2.0
# stick:  3
# 320  --  [2, 0] [3] 3 1
# dealer:  2 playerSum:  3 action:  0 n:  6.0
# 321  --  [2] [6, 15, 18, 14, 4] -6 -1
# dealer:  2 playerSum:  4 action:  1 n:  1.0
# stick:  7
# 322  --  [10, 22] [7] 7 1
# dealer:  10 playerSum:  7 action:  0 n:  5.0
# stick:  10
# 323  --  [10, 18] [10] 10 -1
# dealer:  10 playerSum:  10 action:  0 n:  5.0
# stick:  6
# 324  --  [2, -4] [9, 6] 6 1
# dealer:  2 playerSum:  6 action:  0 n:  2.0
# stick:  9
# 325  --  [1, -1] [1, 9] 9 1
# dealer:  1 playerSum:  9 action:  0 n:  8.0
# stick:  3
# 326  --  [10, 17] [3] 3 -1
# dealer:  10 playerSum:  3 action:  0 n:  4.0
# stick:  6
# 327  --  [8, 20] [6] 6 -1
# dealer:  8 playerSum:  6 action:  0 n:  3.0
# stick:  8
# 328  --  [3, 0] [8] 8 1
# dealer:  3 playerSum:  8 action:  0 n:  10.0
# stick:  5
# 329  --  [5, 0] [5] 5 1
# dealer:  5 playerSum:  5 action:  0 n:  4.0
# stick:  3
# 330  --  [9, 22] [3] 3 1
# dealer:  9 playerSum:  3 action:  0 n:  3.0
# stick:  8
# 331  --  [8, 20] [8] 8 -1
# dealer:  8 playerSum:  8 action:  0 n:  1.0
# stick:  6
# 332  --  [7, -4] [6] 6 1
# dealer:  7 playerSum:  6 action:  0 n:  1.0
# 333  --  [2] [9, 2, 7, 14] 23 -1
# dealer:  2 playerSum:  14 action:  1 n:  2.0
# stick:  13
# 334  --  [8, 24] [9, 13] 13 1
# dealer:  8 playerSum:  13 action:  0 n:  1.0
# stick:  6
# 335  --  [6, 21] [9, 14, 6] 6 -1
# dealer:  6 playerSum:  6 action:  0 n:  3.0
# 336  --  [8] [10, 19] 28 -1
# dealer:  8 playerSum:  19 action:  1 n:  2.0
# 337  --  [4] [2] -7 -1
# dealer:  4 playerSum:  2 action:  1 n:  3.0
# stick:  11
# 338  --  [10, 25] [3, 6, 11] 11 1
# dealer:  10 playerSum:  11 action:  0 n:  1.0
# 339  --  [3] [8, 14] 23 -1
# dealer:  3 playerSum:  14 action:  1 n:  2.0
# stick:  5
# 340  --  [2, -5] [5] 5 1
# dealer:  2 playerSum:  5 action:  0 n:  3.0
# stick:  2
# 341  --  [8, -1] [2] 2 1
# dealer:  8 playerSum:  2 action:  0 n:  2.0
# stick:  5
# 342  --  [1, 19] [5] 5 -1
# dealer:  1 playerSum:  5 action:  0 n:  4.0
# 343  --  [5] [9, 12] 22 -1
# dealer:  5 playerSum:  12 action:  1 n:  1.0
# stick:  4
# 344  --  [3, -1] [4] 4 1
# dealer:  3 playerSum:  4 action:  0 n:  2.0
# stick:  3
# 345  --  [7, 22] [3] 3 1
# dealer:  7 playerSum:  3 action:  0 n:  1.0
# stick:  7
# 346  --  [8, 17] [2, 7] 7 -1
# dealer:  8 playerSum:  7 action:  0 n:  4.0
# stick:  4
# 347  --  [8, 0] [4] 4 1
# dealer:  8 playerSum:  4 action:  0 n:  6.0
# 348  --  [5] [6, 16] 23 -1
# dealer:  5 playerSum:  16 action:  1 n:  1.0
# 349  --  [10] [2] 0 -1
# dealer:  10 playerSum:  2 action:  1 n:  3.0
# stick:  4
# 350  --  [2, 25] [4] 4 1
# dealer:  2 playerSum:  4 action:  0 n:  3.0
# stick:  2
# 351  --  [7, 17] [2] 2 -1
# dealer:  7 playerSum:  2 action:  0 n:  2.0
# stick:  2
# 352  --  [6, 23] [2] 2 1
# dealer:  6 playerSum:  2 action:  0 n:  2.0
# 353  --  [9] [2] 1 -1
# dealer:  9 playerSum:  2 action:  1 n:  5.0
# 354  --  [3] [4] 1 -1
# dealer:  3 playerSum:  4 action:  1 n:  3.0
# stick:  1
# 355  --  [3, 23] [1] 1 1
# dealer:  3 playerSum:  1 action:  0 n:  2.0
# stick:  7
# 356  --  [5, -3] [7] 7 1
# dealer:  5 playerSum:  7 action:  0 n:  4.0
# 357  --  [3] [2] -5 -1
# dealer:  3 playerSum:  2 action:  1 n:  3.0
# 358  --  [8] [2, 9] 0 -1
# dealer:  8 playerSum:  9 action:  1 n:  3.0
# 359  --  [7] [7] 0 -1
# dealer:  7 playerSum:  7 action:  1 n:  1.0
# stick:  7
# 360  --  [7, 24] [7] 7 1
# dealer:  7 playerSum:  7 action:  0 n:  2.0
# stick:  13
# 361  --  [3, 21] [9, 13] 13 -1
# dealer:  3 playerSum:  13 action:  0 n:  2.0
# stick:  1
# 362  --  [10, 19] [1] 1 -1
# dealer:  10 playerSum:  1 action:  0 n:  3.0
# stick:  10
# 363  --  [7, -1] [10] 10 1
# dealer:  7 playerSum:  10 action:  0 n:  5.0
# stick:  10
# 364  --  [8, 0] [10] 10 1
# dealer:  8 playerSum:  10 action:  0 n:  3.0
# 365  --  [10] [9] 1 -1
# dealer:  10 playerSum:  9 action:  1 n:  1.0
# stick:  16
# 366  --  [9, 21] [8, 16] 16 -1
# dealer:  9 playerSum:  16 action:  0 n:  1.0
# stick:  8
# 367  --  [3, 20] [8] 8 -1
# dealer:  3 playerSum:  8 action:  0 n:  11.0
# 368  --  [10] [4] 0 -1
# dealer:  10 playerSum:  4 action:  1 n:  2.0
# stick:  5
# 369  --  [10, 20] [5] 5 -1
# dealer:  10 playerSum:  5 action:  0 n:  1.0
# stick:  4
# 370  --  [5, -1] [4] 4 1
# dealer:  5 playerSum:  4 action:  0 n:  4.0
# stick:  1
# 371  --  [6, 19] [1] 1 -1
# dealer:  6 playerSum:  1 action:  0 n:  2.0
# stick:  8
# 372  --  [5, -3] [2, 8] 8 1
# dealer:  5 playerSum:  8 action:  0 n:  6.0
# stick:  9
# 373  --  [7, 17] [2, 9] 9 -1
# dealer:  7 playerSum:  9 action:  0 n:  3.0
# stick:  3
# 374  --  [5, 18] [3] 3 -1
# dealer:  5 playerSum:  3 action:  0 n:  1.0
# stick:  14
# 375  --  [1, -1] [9, 14] 14 1
# dealer:  1 playerSum:  14 action:  0 n:  3.0
# stick:  10
# 376  --  [4, -1] [10] 10 1
# dealer:  4 playerSum:  10 action:  0 n:  7.0
# stick:  5
# 377  --  [9, 0] [5] 5 1
# dealer:  9 playerSum:  5 action:  0 n:  2.0
# stick:  3
# 378  --  [2, 19] [3] 3 -1
# dealer:  2 playerSum:  3 action:  0 n:  7.0
# stick:  5
# 379  --  [3, -3] [5] 5 1
# dealer:  3 playerSum:  5 action:  0 n:  2.0
# stick:  16
# 380  --  [2, 21] [10, 16] 16 -1
# dealer:  2 playerSum:  16 action:  0 n:  1.0
# stick:  9
# 381  --  [8, -3] [9] 9 1
# dealer:  8 playerSum:  9 action:  0 n:  1.0
# 382  --  [7] [5, 8] 0 -1
# dealer:  7 playerSum:  8 action:  1 n:  4.0
# 383  --  [9] [10, 13, 3] -7 -1
# dealer:  9 playerSum:  3 action:  1 n:  3.0
# 384  --  [7] [3, 11, 18] 25 -1
# dealer:  7 playerSum:  18 action:  1 n:  1.0
# stick:  4
# 385  --  [1, -2] [4] 4 1
# dealer:  1 playerSum:  4 action:  0 n:  3.0
# stick:  10
# 386  --  [2, 17] [10] 10 -1
# dealer:  2 playerSum:  10 action:  0 n:  2.0
# stick:  11
# 387  --  [7, 18] [4, 11] 11 -1
# dealer:  7 playerSum:  11 action:  0 n:  3.0
# stick:  7
# 388  --  [2, 18] [4, 7] 7 -1
# dealer:  2 playerSum:  7 action:  0 n:  3.0
# stick:  1
# 389  --  [1, -4] [1] 1 1
# dealer:  1 playerSum:  1 action:  0 n:  3.0
# 390  --  [10] [10, 13] 21 -1
# dealer:  10 playerSum:  13 action:  1 n:  1.0
# stick:  2
# 391  --  [1, 18] [2] 2 -1
# dealer:  1 playerSum:  2 action:  0 n:  2.0
# stick:  7
# 392  --  [7, 18] [7] 7 -1
# dealer:  7 playerSum:  7 action:  0 n:  3.0
# stick:  7
# 393  --  [1, -8] [7] 7 1
# dealer:  1 playerSum:  7 action:  0 n:  3.0
# stick:  8
# 394  --  [10, 18] [8] 8 -1
# dealer:  10 playerSum:  8 action:  0 n:  4.0
# stick:  9
# 395  --  [7, 22] [8, 9] 9 1
# dealer:  7 playerSum:  9 action:  0 n:  4.0
# stick:  16
# 396  --  [3, -5] [5, 8, 6, 13, 17, 8, 16] 16 1
# dealer:  3 playerSum:  16 action:  0 n:  1.0
# stick:  8
# 397  --  [7, 17] [5, 8] 8 -1
# dealer:  7 playerSum:  8 action:  0 n:  2.0
# stick:  4
# 398  --  [6, -2] [2, 4] 4 1
# dealer:  6 playerSum:  4 action:  0 n:  3.0
# stick:  3
# 399  --  [5, -3] [3] 3 1
# dealer:  5 playerSum:  3 action:  0 n:  2.0
# stick:  12
# 400  --  [4, 23] [7, 12] 12 1
# dealer:  4 playerSum:  12 action:  0 n:  1.0
# stick:  9
# 401  --  [7, 19] [6, 9] 9 -1
# dealer:  7 playerSum:  9 action:  0 n:  5.0
# stick:  8
# 402  --  [1, 18] [8] 8 -1
# dealer:  1 playerSum:  8 action:  0 n:  4.0
# stick:  14
# 403  --  [2, -4] [1, 10, 14] 14 1
# dealer:  2 playerSum:  14 action:  0 n:  1.0
# 404  --  [4] [5, 9, 19] 22 -1
# dealer:  4 playerSum:  19 action:  1 n:  1.0
# stick:  6
# 405  --  [2, -5] [6] 6 1
# dealer:  2 playerSum:  6 action:  0 n:  3.0
# stick:  10
# 406  --  [2, 17] [10] 10 -1
# dealer:  2 playerSum:  10 action:  0 n:  3.0
# 407  --  [1] [9, 2] -3 -1
# dealer:  1 playerSum:  2 action:  1 n:  4.0
# stick:  11
# 408  --  [3, 18] [6, 11] 11 -1
# dealer:  3 playerSum:  11 action:  0 n:  3.0
# stick:  10
# 409  --  [9, 17] [10] 10 -1
# dealer:  9 playerSum:  10 action:  0 n:  5.0
# stick:  12
# 410  --  [8, 0] [4, 12] 12 1
# dealer:  8 playerSum:  12 action:  0 n:  1.0
# stick:  3
# 411  --  [10, 22] [3] 3 1
# dealer:  10 playerSum:  3 action:  0 n:  5.0
# 412  --  [8] [10] 1 -1
# dealer:  8 playerSum:  10 action:  1 n:  5.0
# stick:  8
# 413  --  [4, 0] [8] 8 1
# dealer:  4 playerSum:  8 action:  0 n:  4.0
# stick:  10
# 414  --  [6, 0] [10] 10 1
# dealer:  6 playerSum:  10 action:  0 n:  6.0
# stick:  2
# 415  --  [6, -2] [2, 5, 2] 2 1
# dealer:  6 playerSum:  2 action:  0 n:  3.0
# 416  --  [8] [5] -5 -1
# dealer:  8 playerSum:  5 action:  1 n:  3.0
# stick:  6
# 417  --  [1, -1] [6] 6 1
# dealer:  1 playerSum:  6 action:  0 n:  3.0
# stick:  5
# 418  --  [2, 20] [5] 5 -1
# dealer:  2 playerSum:  5 action:  0 n:  4.0
# stick:  7
# 419  --  [10, -6] [7] 7 1
# dealer:  10 playerSum:  7 action:  0 n:  6.0
# 420  --  [2] [1] -6 -1
# dealer:  2 playerSum:  1 action:  1 n:  3.0
# stick:  3
# 421  --  [9, 17] [3] 3 -1
# dealer:  9 playerSum:  3 action:  0 n:  4.0
# stick:  2
# 422  --  [7, 23] [1, 2] 2 1
# dealer:  7 playerSum:  2 action:  0 n:  3.0
# stick:  2
# 423  --  [2, -1] [4, 2] 2 1
# dealer:  2 playerSum:  2 action:  0 n:  4.0
# 424  --  [4] [7] 0 -1
# dealer:  4 playerSum:  7 action:  1 n:  5.0
# stick:  3
# 425  --  [6, 20] [3] 3 -1
# dealer:  6 playerSum:  3 action:  0 n:  2.0
# 426  --  [6] [10] 1 -1
# dealer:  6 playerSum:  10 action:  1 n:  4.0
# stick:  4
# 427  --  [3, -2] [10, 4] 4 1
# dealer:  3 playerSum:  4 action:  0 n:  3.0
# stick:  1
# 428  --  [1, -4] [1] 1 1
# dealer:  1 playerSum:  1 action:  0 n:  4.0
# stick:  15
# 429  --  [10, 22] [7, 13, 15] 15 1
# dealer:  10 playerSum:  15 action:  0 n:  1.0
# stick:  3
# 430  --  [3, -2] [3] 3 1
# dealer:  3 playerSum:  3 action:  0 n:  2.0
# 431  --  [5] [6, 14, 20] 21 -1
# dealer:  5 playerSum:  20 action:  1 n:  1.0
# stick:  11
# 432  --  [2, 25] [8, 11] 11 1
# dealer:  2 playerSum:  11 action:  0 n:  3.0
# stick:  1
# 433  --  [3, -4] [1] 1 1
# dealer:  3 playerSum:  1 action:  0 n:  3.0
# stick:  20
# 434  --  [5, 20] [6, 15, 20, 20] 24 -1
# dealer:  5 playerSum:  20 action:  1 n:  2.0
# stick:  9
# 435  --  [6, -1] [7, 9] 9 1
# dealer:  6 playerSum:  9 action:  0 n:  2.0
# stick:  7
# 436  --  [5, 18] [4, 7] 7 -1
# dealer:  5 playerSum:  7 action:  0 n:  5.0
# stick:  2
# 437  --  [2, 21] [1, 2] 2 -1
# dealer:  2 playerSum:  2 action:  0 n:  5.0
# stick:  6
# 438  --  [1, 23] [6] 6 1
# dealer:  1 playerSum:  6 action:  0 n:  4.0
# stick:  2
# 439  --  [1, 22] [2] 2 1
# dealer:  1 playerSum:  2 action:  0 n:  3.0
# stick:  12
# 440  --  [6, -3] [8, 12] 12 1
# dealer:  6 playerSum:  12 action:  0 n:  2.0
# stick:  6
# 441  --  [5, 0] [6] 6 1
# dealer:  5 playerSum:  6 action:  0 n:  4.0
# stick:  7
# 442  --  [8, 24] [7] 7 1
# dealer:  8 playerSum:  7 action:  0 n:  5.0
# 443  --  [6] [2, 10] 0 -1
# dealer:  6 playerSum:  10 action:  1 n:  5.0
# stick:  6
# 444  --  [7, -6] [6] 6 1
# dealer:  7 playerSum:  6 action:  0 n:  2.0
# stick:  3
# 445  --  [10, 19] [3] 3 -1
# dealer:  10 playerSum:  3 action:  0 n:  6.0
# stick:  4
# 446  --  [9, 17] [4] 4 -1
# dealer:  9 playerSum:  4 action:  0 n:  1.0
# stick:  8
# 447  --  [6, -1] [8] 8 1
# dealer:  6 playerSum:  8 action:  0 n:  6.0
# stick:  3
# 448  --  [6, -1] [3] 3 1
# dealer:  6 playerSum:  3 action:  0 n:  3.0
# stick:  9
# 449  --  [5, 19] [9] 9 -1
# dealer:  5 playerSum:  9 action:  0 n:  2.0
# stick:  4
# 450  --  [7, 22] [1, 4] 4 1
# dealer:  7 playerSum:  4 action:  0 n:  5.0
# stick:  18
# 451  --  [1, -1] [9, 11, 18] 18 1
# dealer:  1 playerSum:  18 action:  0 n:  1.0
# stick:  4
# 452  --  [1, 17] [6, 4] 4 -1
# dealer:  1 playerSum:  4 action:  0 n:  4.0
# stick:  14
# 453  --  [8, -1] [5, 7, 14] 14 1
# dealer:  8 playerSum:  14 action:  0 n:  3.0
# stick:  9
# 454  --  [8, 24] [9] 9 1
# dealer:  8 playerSum:  9 action:  0 n:  2.0
# 455  --  [9] [10, 19] 23 -1
# dealer:  9 playerSum:  19 action:  1 n:  1.0
# stick:  19
# 456  --  [8, 17] [9, 19] 19 1
# dealer:  8 playerSum:  19 action:  0 n:  2.0
# stick:  11
# 457  --  [5, -3] [9, 4, 9, 6, 11] 11 1
# dealer:  5 playerSum:  11 action:  0 n:  2.0
# 458  --  [10] [2, 9, 17, 20] 24 -1
# dealer:  10 playerSum:  20 action:  1 n:  1.0
# 459  --  [10] [4] -1 -1
# dealer:  10 playerSum:  4 action:  1 n:  3.0
# stick:  15
# 460  --  [7, -2] [10, 14, 15] 15 1
# dealer:  7 playerSum:  15 action:  0 n:  1.0
# stick:  4
# 461  --  [7, -1] [4] 4 1
# dealer:  7 playerSum:  4 action:  0 n:  6.0
# stick:  15
# 462  --  [9, 19] [9, 15] 15 -1
# dealer:  9 playerSum:  15 action:  0 n:  1.0
# stick:  12
# 463  --  [10, 17] [4, 12] 12 -1
# dealer:  10 playerSum:  12 action:  0 n:  3.0
# 464  --  [10] [3, 4] -6 -1
# dealer:  10 playerSum:  4 action:  1 n:  5.0
# stick:  5
# 465  --  [5, 24] [5] 5 1
# dealer:  5 playerSum:  5 action:  0 n:  5.0
# stick:  1
# 466  --  [9, 18] [1] 1 -1
# dealer:  9 playerSum:  1 action:  0 n:  2.0
# stick:  9
# 467  --  [2, 21] [9] 9 -1
# dealer:  2 playerSum:  9 action:  0 n:  2.0
# stick:  9
# 468  --  [6, 23] [9] 9 1
# dealer:  6 playerSum:  9 action:  0 n:  3.0
# stick:  2
# 469  --  [4, 0] [2] 2 1
# dealer:  4 playerSum:  2 action:  0 n:  3.0
# stick:  15
# 470  --  [8, 22] [6, 15] 15 1
# dealer:  8 playerSum:  15 action:  0 n:  1.0
# stick:  1
# 471  --  [2, 21] [1] 1 -1
# dealer:  2 playerSum:  1 action:  0 n:  2.0
# stick:  2
# 472  --  [8, -6] [2] 2 1
# dealer:  8 playerSum:  2 action:  0 n:  3.0
# stick:  4
# 473  --  [4, 20] [4] 4 -1
# dealer:  4 playerSum:  4 action:  0 n:  2.0
# 474  --  [1] [8, 14, 20] 26 -1
# dealer:  1 playerSum:  20 action:  1 n:  1.0
# stick:  7
# 475  --  [8, -3] [7] 7 1
# dealer:  8 playerSum:  7 action:  0 n:  6.0
# stick:  8
# 476  --  [2, 18] [8] 8 -1
# dealer:  2 playerSum:  8 action:  0 n:  2.0
# stick:  7
# 477  --  [6, -4] [7] 7 1
# dealer:  6 playerSum:  7 action:  0 n:  4.0
# stick:  5
# 478  --  [1, 17] [8, 11, 5] 5 -1
# dealer:  1 playerSum:  5 action:  0 n:  5.0
# stick:  8
# 479  --  [2, -1] [8] 8 1
# dealer:  2 playerSum:  8 action:  0 n:  3.0
# stick:  3
# 480  --  [8, 23] [3] 3 1
# dealer:  8 playerSum:  3 action:  0 n:  1.0
# stick:  6
# 481  --  [8, 17] [7, 5, 6] 6 -1
# dealer:  8 playerSum:  6 action:  0 n:  4.0
# stick:  10
# 482  --  [5, 17] [10] 10 -1
# dealer:  5 playerSum:  10 action:  0 n:  4.0
# stick:  13
# 483  --  [1, 18] [6, 13] 13 -1
# dealer:  1 playerSum:  13 action:  0 n:  1.0
# stick:  20
# 484  --  [2, 22] [10, 3, 11, 20] 20 1
# dealer:  2 playerSum:  20 action:  0 n:  1.0
# stick:  8
# 485  --  [5, -3] [8] 8 1
# dealer:  5 playerSum:  8 action:  0 n:  7.0
# stick:  7
# 486  --  [1, 19] [7] 7 -1
# dealer:  1 playerSum:  7 action:  0 n:  4.0
# stick:  12
# 487  --  [2, -8] [5, 12] 12 1
# dealer:  2 playerSum:  12 action:  0 n:  1.0
# stick:  9
# 488  --  [6, 20] [9] 9 -1
# dealer:  6 playerSum:  9 action:  0 n:  4.0
# stick:  9
# 489  --  [7, 25] [5, 9] 9 1
# dealer:  7 playerSum:  9 action:  0 n:  6.0
# stick:  17
# 490  --  [4, 18] [4, 14, 17] 17 -1
# dealer:  4 playerSum:  17 action:  0 n:  1.0
# stick:  1
# 491  --  [9, 17] [1] 1 -1
# dealer:  9 playerSum:  1 action:  0 n:  3.0
# stick:  6
# 492  --  [4, 23] [1, 6] 6 1
# dealer:  4 playerSum:  6 action:  0 n:  1.0
# 493  --  [7] [1] -5 -1
# dealer:  7 playerSum:  1 action:  1 n:  3.0
# 494  --  [6] [5] -3 -1
# dealer:  6 playerSum:  5 action:  1 n:  5.0
# stick:  19
# 495  --  [8, 17] [8, 15, 19] 19 1
# dealer:  8 playerSum:  19 action:  0 n:  3.0
# stick:  15
# 496  --  [1, 17] [10, 11, 15] 15 -1
# dealer:  1 playerSum:  15 action:  0 n:  2.0
# stick:  3
# 497  --  [1, -3] [3] 3 1
# dealer:  1 playerSum:  3 action:  0 n:  4.0
# stick:  15
# 498  --  [7, 23] [5, 15] 15 1
# dealer:  7 playerSum:  15 action:  0 n:  2.0
# stick:  3
# 499  --  [4, 22] [3] 3 1
# dealer:  4 playerSum:  3 action:  0 n:  3.0
# 500  --  [10] [7, 14] 23 -1
# dealer:  10 playerSum:  14 action:  1 n:  1.0
# stick:  8
# 501  --  [10, 19] [1, 8] 8 -1
# dealer:  10 playerSum:  8 action:  0 n:  5.0
# stick:  3
# 502  --  [9, -3] [3] 3 1
# dealer:  9 playerSum:  3 action:  0 n:  5.0
# stick:  6
# 503  --  [6, -2] [1, 6] 6 1
# dealer:  6 playerSum:  6 action:  0 n:  4.0
# stick:  3
# 504  --  [2, 22] [9, 3] 3 1
# dealer:  2 playerSum:  3 action:  0 n:  8.0
# stick:  18
# stick:  18
# 505  --  [3, 18, 21] [5, 10, 18, 12, 15, 18, 18] 18 -1
# dealer:  3 playerSum:  18 action:  0 n:  2.0
# stick:  5
# 506  --  [7, 21] [5] 5 -1
# dealer:  7 playerSum:  5 action:  0 n:  5.0
# stick:  5
# 507  --  [7, 20] [5] 5 -1
# dealer:  7 playerSum:  5 action:  0 n:  6.0
# stick:  2
# 508  --  [9, 22] [2] 2 1
# dealer:  9 playerSum:  2 action:  0 n:  2.0
# stick:  15
# 509  --  [3, 18] [6, 15] 15 -1
# dealer:  3 playerSum:  15 action:  0 n:  2.0
# stick:  1
# 510  --  [2, 20] [1] 1 -1
# dealer:  2 playerSum:  1 action:  0 n:  3.0
# stick:  14
# 511  --  [10, 18] [3, 4, 14] 14 -1
# dealer:  10 playerSum:  14 action:  0 n:  2.0
# stick:  14
# 512  --  [9, 19] [3, 4, 11, 14] 14 -1
# dealer:  9 playerSum:  14 action:  0 n:  3.0
# stick:  13
# 513  --  [3, 20] [7, 13] 13 -1
# dealer:  3 playerSum:  13 action:  0 n:  3.0
# stick:  1
# 514  --  [9, 18] [1] 1 -1
# dealer:  9 playerSum:  1 action:  0 n:  4.0
# stick:  1
# 515  --  [9, 17] [1] 1 -1
# dealer:  9 playerSum:  1 action:  0 n:  5.0
# stick:  2
# 516  --  [10, 17] [2] 2 -1
# dealer:  10 playerSum:  2 action:  0 n:  1.0
# stick:  10
# 517  --  [5, 17] [8, 10] 10 -1
# dealer:  5 playerSum:  10 action:  0 n:  5.0
# stick:  9
# 518  --  [4, -4] [9] 9 1
# dealer:  4 playerSum:  9 action:  0 n:  1.0
# stick:  10
# 519  --  [4, 17] [10] 10 -1
# dealer:  4 playerSum:  10 action:  0 n:  8.0
# stick:  6
# 520  --  [6, 18] [6] 6 -1
# dealer:  6 playerSum:  6 action:  0 n:  5.0
# 521  --  [7] [5] -3 -1
# dealer:  7 playerSum:  5 action:  1 n:  6.0
# stick:  5
# 522  --  [10, 20] [8, 4, 5] 5 -1
# dealer:  10 playerSum:  5 action:  0 n:  2.0
# stick:  1
# 523  --  [10, 18] [1] 1 -1
# dealer:  10 playerSum:  1 action:  0 n:  4.0
# 524  --  [8] [7, 17] 25 -1
# dealer:  8 playerSum:  17 action:  1 n:  1.0
# stick:  7
# 525  --  [6, 22] [7] 7 1
# dealer:  6 playerSum:  7 action:  0 n:  5.0
# stick:  10
# 526  --  [9, 19] [10] 10 -1
# dealer:  9 playerSum:  10 action:  0 n:  6.0
# stick:  12
# 527  --  [10, 20] [9, 12] 12 -1
# dealer:  10 playerSum:  12 action:  0 n:  4.0
# stick:  8
# 528  --  [5, -1] [8] 8 1
# dealer:  5 playerSum:  8 action:  0 n:  8.0
# stick:  9
# 529  --  [6, 18] [9] 9 -1
# dealer:  6 playerSum:  9 action:  0 n:  5.0
# stick:  7
# 530  --  [2, 18] [7] 7 -1
# dealer:  2 playerSum:  7 action:  0 n:  4.0
# stick:  7
# 531  --  [2, 24] [7] 7 1
# dealer:  2 playerSum:  7 action:  0 n:  5.0
# stick:  1
# 532  --  [5, -2] [1] 1 1
# dealer:  5 playerSum:  1 action:  0 n:  4.0
# stick:  8
# 533  --  [9, 18] [8] 8 -1
# dealer:  9 playerSum:  8 action:  0 n:  2.0
# stick:  1
# 534  --  [2, -2] [1] 1 1
# dealer:  2 playerSum:  1 action:  0 n:  4.0
# 535  --  [9] [4, 14] 21 -1
# dealer:  9 playerSum:  14 action:  1 n:  1.0
# stick:  8
# 536  --  [9, -1] [1, 8] 8 1
# dealer:  9 playerSum:  8 action:  0 n:  3.0
# stick:  9
# 537  --  [8, 18] [9] 9 -1
# dealer:  8 playerSum:  9 action:  0 n:  3.0
# 538  --  [4] [10, 9] 1 -1
# dealer:  4 playerSum:  9 action:  1 n:  4.0
# stick:  2
# 539  --  [3, -1] [2] 2 1
# dealer:  3 playerSum:  2 action:  0 n:  3.0
# stick:  2
# 540  --  [10, 0] [2] 2 1
# dealer:  10 playerSum:  2 action:  0 n:  2.0
# stick:  16
# 541  --  [4, 22] [8, 18, 16] 16 1
# dealer:  4 playerSum:  16 action:  0 n:  2.0
# stick:  4
# 542  --  [9, 20] [4] 4 -1
# dealer:  9 playerSum:  4 action:  0 n:  2.0
# stick:  10
# 543  --  [3, 19] [10] 10 -1
# dealer:  3 playerSum:  10 action:  0 n:  4.0
# stick:  9
# 544  --  [6, 25] [9] 9 1
# dealer:  6 playerSum:  9 action:  0 n:  6.0
# stick:  9
# 545  --  [4, 18] [9] 9 -1
# dealer:  4 playerSum:  9 action:  0 n:  2.0
# stick:  17
# 546  --  [2, -6] [9, 17] 17 1
# dealer:  2 playerSum:  17 action:  0 n:  1.0
# stick:  16
# 547  --  [5, 18] [7, 16] 16 -1
# dealer:  5 playerSum:  16 action:  0 n:  1.0
# stick:  8
# 548  --  [9, 18] [8] 8 -1
# dealer:  9 playerSum:  8 action:  0 n:  4.0
# 549  --  [5] [5, 7] -2 -1
# dealer:  5 playerSum:  7 action:  1 n:  2.0
# stick:  7
# 550  --  [6, -3] [7] 7 1
# dealer:  6 playerSum:  7 action:  0 n:  6.0
# stick:  1
# 551  --  [4, 24] [1] 1 1
# dealer:  4 playerSum:  1 action:  0 n:  4.0
# stick:  6
# 552  --  [5, 20] [2, 6] 6 -1
# dealer:  5 playerSum:  6 action:  0 n:  5.0
# stick:  8
# 553  --  [2, -7] [8] 8 1
# dealer:  2 playerSum:  8 action:  0 n:  4.0
# stick:  3
# 554  --  [3, -4] [3] 3 1
# dealer:  3 playerSum:  3 action:  0 n:  3.0
# stick:  7
# 555  --  [2, -8] [7] 7 1
# dealer:  2 playerSum:  7 action:  0 n:  6.0
# stick:  6
# 556  --  [1, 0] [5, 6] 6 1
# dealer:  1 playerSum:  6 action:  0 n:  5.0
# stick:  19
# 557  --  [4, -5] [5, 13, 19] 19 1
# dealer:  4 playerSum:  19 action:  0 n:  1.0
# 558  --  [9] [1] -7 -1
# dealer:  9 playerSum:  1 action:  1 n:  4.0
# stick:  10
# 559  --  [5, -5] [10] 10 1
# dealer:  5 playerSum:  10 action:  0 n:  6.0
# stick:  8
# 560  --  [3, -4] [6, 8] 8 1
# dealer:  3 playerSum:  8 action:  0 n:  12.0
# stick:  4
# 561  --  [4, 17] [2, 4] 4 -1
# dealer:  4 playerSum:  4 action:  0 n:  3.0
# stick:  12
# 562  --  [8, 19] [3, 7, 8, 12] 12 -1
# dealer:  8 playerSum:  12 action:  0 n:  2.0
# stick:  9
# 563  --  [7, 17] [9] 9 -1
# dealer:  7 playerSum:  9 action:  0 n:  7.0
# stick:  2
# 564  --  [10, 19] [2] 2 -1
# dealer:  10 playerSum:  2 action:  0 n:  3.0
# stick:  7
# 565  --  [10, 20] [7] 7 -1
# dealer:  10 playerSum:  7 action:  0 n:  7.0
# 566  --  [10] [9, 11] 1 -1
# dealer:  10 playerSum:  11 action:  1 n:  1.0
# stick:  8
# 567  --  [6, 23] [3, 8] 8 1
# dealer:  6 playerSum:  8 action:  0 n:  7.0
# stick:  2
# 568  --  [8, 0] [2] 2 1
# dealer:  8 playerSum:  2 action:  0 n:  4.0
# stick:  19
# 569  --  [5, 18] [9, 19] 19 1
# dealer:  5 playerSum:  19 action:  0 n:  1.0
# stick:  19
# 570  --  [7, 18] [9, 19] 19 1
# dealer:  7 playerSum:  19 action:  0 n:  1.0
# stick:  15
# 571  --  [1, 0] [9, 14, 15] 15 1
# dealer:  1 playerSum:  15 action:  0 n:  3.0
# stick:  3
# 572  --  [1, 17] [3] 3 -1
# dealer:  1 playerSum:  3 action:  0 n:  5.0
# 573  --  [3] [5, 13] 21 -1
# dealer:  3 playerSum:  13 action:  1 n:  3.0
# stick:  2
# 574  --  [6, -1] [1, 2] 2 1
# dealer:  6 playerSum:  2 action:  0 n:  4.0
# stick:  13
# 575  --  [3, 17] [3, 13] 13 -1
# dealer:  3 playerSum:  13 action:  0 n:  4.0
# stick:  7
# 576  --  [2, 17] [3, 7, 3, 13, 7] 7 -1
# dealer:  2 playerSum:  7 action:  0 n:  7.0
# 577  --  [9] [7] -3 -1
# dealer:  9 playerSum:  7 action:  1 n:  4.0
# stick:  2
# 578  --  [8, 17] [9, 2] 2 -1
# dealer:  8 playerSum:  2 action:  0 n:  5.0
# stick:  2
# 579  --  [9, 20] [2] 2 -1
# dealer:  9 playerSum:  2 action:  0 n:  3.0
# stick:  13
# 580  --  [4, 0] [1, 10, 13] 13 1
# dealer:  4 playerSum:  13 action:  0 n:  1.0
# stick:  7
# 581  --  [9, 21] [7] 7 -1
# dealer:  9 playerSum:  7 action:  0 n:  2.0
# stick:  9
# 582  --  [1, -3] [9] 9 1
# dealer:  1 playerSum:  9 action:  0 n:  9.0
# 583  --  [7] [7] -3 -1
# dealer:  7 playerSum:  7 action:  1 n:  2.0
# 584  --  [7] [1, 10] 1 -1
# dealer:  7 playerSum:  10 action:  1 n:  4.0
# stick:  9
# 585  --  [4, 25] [7, 9] 9 1
# dealer:  4 playerSum:  9 action:  0 n:  3.0
# stick:  3
# 586  --  [9, 18] [3] 3 -1
# dealer:  9 playerSum:  3 action:  0 n:  6.0
# stick:  6
# 587  --  [6, 25] [6] 6 1
# dealer:  6 playerSum:  6 action:  0 n:  6.0
# stick:  1
# 588  --  [9, -1] [1] 1 1
# dealer:  9 playerSum:  1 action:  0 n:  6.0
# stick:  12
# 589  --  [5, -1] [9, 12] 12 1
# dealer:  5 playerSum:  12 action:  0 n:  1.0
# stick:  14
# 590  --  [4, 19] [5, 14] 14 -1
# dealer:  4 playerSum:  14 action:  0 n:  1.0
# stick:  9
# 591  --  [10, -1] [9] 9 1
# dealer:  10 playerSum:  9 action:  0 n:  1.0
# stick:  13
# 592  --  [5, -1] [7, 13] 13 1
# dealer:  5 playerSum:  13 action:  0 n:  1.0
# stick:  15
# 593  --  [7, 22] [7, 15] 15 1
# dealer:  7 playerSum:  15 action:  0 n:  3.0
# stick:  3
# 594  --  [5, 21] [3] 3 -1
# dealer:  5 playerSum:  3 action:  0 n:  3.0
# 595  --  [8] [10, 4, 13, 17] 21 -1
# dealer:  8 playerSum:  17 action:  1 n:  2.0
# stick:  6
# 596  --  [8, 23] [6] 6 1
# dealer:  8 playerSum:  6 action:  0 n:  5.0
# stick:  1
# 597  --  [7, 26] [1] 1 1
# dealer:  7 playerSum:  1 action:  0 n:  2.0
# ...
# stick:  4
# 5375  --  [3, 0] [4] 4 1
# dealer:  3 playerSum:  4 action:  0 n:  36.0
# stick:  15
# 5376  --  [5, -1] [5, 15] 15 1
# dealer:  5 playerSum:  15 action:  0 n:  10.0
# stick:  14
# 5377  --  [5, 23] [6, 14] 14 1
# dealer:  5 playerSum:  14 action:  0 n:  9.0
# stick:  1
# 5378  --  [1, 22] [1] 1 1
# dealer:  1 playerSum:  1 action:  0 n:  36.0
# stick:  3
# 5379  --  [10, 19] [3] 3 -1
# dealer:  10 playerSum:  3 action:  0 n:  30.0
# stick:  10
# 5380  --  [6, 0] [10] 10 1
# dealer:  6 playerSum:  10 action:  0 n:  60.0
# stick:  9
# 5381  --  [5, 18] [9] 9 -1
# dealer:  5 playerSum:  9 action:  0 n:  30.0
# stick:  3
# 5382  --  [2, 19] [2, 4, 3] 3 -1
# dealer:  2 playerSum:  3 action:  0 n:  37.0
# 5383  --  [6] [2] -1 -1
# dealer:  6 playerSum:  2 action:  1 n:  47.0
# stick:  1
# 5384  --  [6, 19] [1] 1 -1
# dealer:  6 playerSum:  1 action:  0 n:  26.0
# stick:  4
# 5385  --  [9, 17] [4] 4 -1
# dealer:  9 playerSum:  4 action:  0 n:  29.0
# stick:  8
# 5386  --  [9, 19] [8] 8 -1
# dealer:  9 playerSum:  8 action:  0 n:  32.0
# stick:  17
# 5387  --  [3, 21] [8, 18, 17] 17 -1
# dealer:  3 playerSum:  17 action:  0 n:  6.0
# stick:  10
# 5388  --  [8, 25] [6, 10] 10 1
# dealer:  8 playerSum:  10 action:  0 n:  26.0
# stick:  3
# 5389  --  [5, 0] [3] 3 1
# dealer:  5 playerSum:  3 action:  0 n:  56.0
# 5390  --  [1] [1] -5 -1
# dealer:  1 playerSum:  1 action:  1 n:  39.0
# stick:  4
# 5391  --  [9, 18] [4] 4 -1
# dealer:  9 playerSum:  4 action:  0 n:  30.0
# stick:  14
# 5392  --  [4, -1] [8, 14] 14 1
# dealer:  4 playerSum:  14 action:  0 n:  9.0
# stick:  6
# 5393  --  [2, 18] [6] 6 -1
# dealer:  2 playerSum:  6 action:  0 n:  34.0
# stick:  5
# 5394  --  [9, 20] [5] 5 -1
# dealer:  9 playerSum:  5 action:  0 n:  42.0
# stick:  3
# 5395  --  [6, 20] [3] 3 -1
# dealer:  6 playerSum:  3 action:  0 n:  33.0
# stick:  7
# 5396  --  [9, 0] [7] 7 1
# dealer:  9 playerSum:  7 action:  0 n:  42.0
# stick:  7
# 5397  --  [10, 0] [7] 7 1
# dealer:  10 playerSum:  7 action:  0 n:  38.0
# stick:  8
# 5398  --  [5, -3] [8] 8 1
# dealer:  5 playerSum:  8 action:  0 n:  41.0
# stick:  4
# 5399  --  [4, -3] [4] 4 1
# dealer:  4 playerSum:  4 action:  0 n:  35.0
# stick:  1
# 5400  --  [7, 18] [1] 1 -1
# dealer:  7 playerSum:  1 action:  0 n:  26.0
# 5401  --  [4] [4] -2 -1
# dealer:  4 playerSum:  4 action:  1 n:  27.0
# stick:  8
# 5402  --  [6, 25] [8] 8 1
# dealer:  6 playerSum:  8 action:  0 n:  32.0
# stick:  8
# 5403  --  [8, 25] [4, 8] 8 1
# dealer:  8 playerSum:  8 action:  0 n:  32.0
# stick:  10
# 5404  --  [4, 19] [5, 10] 10 -1
# dealer:  4 playerSum:  10 action:  0 n:  43.0
# stick:  12
# 5405  --  [4, 20] [9, 12] 12 -1
# dealer:  4 playerSum:  12 action:  0 n:  11.0
# stick:  5
# 5406  --  [1, -7] [4, 5] 5 1
# dealer:  1 playerSum:  5 action:  0 n:  37.0
# 5407  --  [9] [1, 8, 6, 16] 21 -1
# dealer:  9 playerSum:  16 action:  1 n:  8.0
# stick:  3
# 5408  --  [10, 20] [3] 3 -1
# dealer:  10 playerSum:  3 action:  0 n:  31.0
# stick:  8
# 5409  --  [4, 19] [8] 8 -1
# dealer:  4 playerSum:  8 action:  0 n:  48.0
# stick:  3
# 5410  --  [4, 18] [3] 3 -1
# dealer:  4 playerSum:  3 action:  0 n:  28.0
# stick:  20
# 5411  --  [9, 17] [5, 8, 10, 20] 20 1
# dealer:  9 playerSum:  20 action:  0 n:  6.0
# stick:  9
# 5412  --  [1, 0] [4, 9] 9 1
# dealer:  1 playerSum:  9 action:  0 n:  33.0
# stick:  10
# 5413  --  [10, 0] [9, 10, 17, 10] 10 1
# dealer:  10 playerSum:  10 action:  0 n:  37.0
# 5414  --  [3] [2, 8, 17] 25 -1
# dealer:  3 playerSum:  17 action:  1 n:  10.0
# stick:  5
# 5415  --  [8, 18] [2, 5] 5 -1
# dealer:  8 playerSum:  5 action:  0 n:  34.0
# stick:  4
# 5416  --  [1, 26] [4] 4 1
# dealer:  1 playerSum:  4 action:  0 n:  32.0
# stick:  9
# 5417  --  [8, 19] [9] 9 -1
# dealer:  8 playerSum:  9 action:  0 n:  41.0
# stick:  9
# 5418  --  [3, -7] [9] 9 1
# dealer:  3 playerSum:  9 action:  0 n:  32.0
# stick:  9
# 5419  --  [6, 18] [9] 9 -1
# dealer:  6 playerSum:  9 action:  0 n:  38.0
# stick:  8
# 5420  --  [7, -2] [8] 8 1
# dealer:  7 playerSum:  8 action:  0 n:  37.0
# stick:  3
# 5421  --  [5, 23] [3] 3 1
# dealer:  5 playerSum:  3 action:  0 n:  57.0
# stick:  6
# 5422  --  [4, 21] [6] 6 -1
# dealer:  4 playerSum:  6 action:  0 n:  19.0
# stick:  16
# 5423  --  [3, -7] [7, 16] 16 1
# dealer:  3 playerSum:  16 action:  0 n:  12.0
# stick:  3
# 5424  --  [10, 19] [3] 3 -1
# dealer:  10 playerSum:  3 action:  0 n:  32.0
# stick:  6
# 5425  --  [10, 17] [6] 6 -1
# dealer:  10 playerSum:  6 action:  0 n:  32.0
# stick:  17
# 5426  --  [1, -1] [7, 13, 17] 17 1
# dealer:  1 playerSum:  17 action:  0 n:  6.0
# stick:  1
# 5427  --  [2, -5] [1] 1 1
# dealer:  2 playerSum:  1 action:  0 n:  31.0
# stick:  7
# 5428  --  [9, 19] [7] 7 -1
# dealer:  9 playerSum:  7 action:  0 n:  43.0
# stick:  5
# 5429  --  [8, 19] [5] 5 -1
# dealer:  8 playerSum:  5 action:  0 n:  35.0
# stick:  8
# 5430  --  [7, 19] [8] 8 -1
# dealer:  7 playerSum:  8 action:  0 n:  38.0
# stick:  10
# 5431  --  [9, 24] [10] 10 1
# dealer:  9 playerSum:  10 action:  0 n:  32.0
# stick:  12
# 5432  --  [10, 18] [6, 15, 10, 12] 12 -1
# dealer:  10 playerSum:  12 action:  0 n:  13.0
# stick:  5
# 5433  --  [6, -7] [5] 5 1
# dealer:  6 playerSum:  5 action:  0 n:  35.0
# stick:  10
# 5434  --  [5, -2] [10] 10 1
# dealer:  5 playerSum:  10 action:  0 n:  42.0
# 5435  --  [7] [10] 1 -1
# dealer:  7 playerSum:  10 action:  1 n:  40.0
# stick:  4
# 5436  --  [6, -4] [4] 4 1
# dealer:  6 playerSum:  4 action:  0 n:  36.0
# stick:  9
# 5437  --  [3, -5] [9] 9 1
# dealer:  3 playerSum:  9 action:  0 n:  33.0
# stick:  16
# 5438  --  [8, 25] [10, 7, 16] 16 1
# dealer:  8 playerSum:  16 action:  0 n:  12.0
# stick:  3
# 5439  --  [9, 17] [3] 3 -1
# dealer:  9 playerSum:  3 action:  0 n:  38.0
# stick:  17
# 5440  --  [3, -2] [9, 17] 17 1
# dealer:  3 playerSum:  17 action:  0 n:  7.0
# stick:  10
# 5441  --  [7, 18] [4, 10] 10 -1
# dealer:  7 playerSum:  10 action:  0 n:  42.0
# stick:  1
# 5442  --  [8, 22] [1] 1 1
# dealer:  8 playerSum:  1 action:  0 n:  26.0
# 5443  --  [1] [6, 13, 20] 25 -1
# dealer:  1 playerSum:  20 action:  1 n:  7.0
# stick:  6
# 5444  --  [1, -6] [4, 2, 4, 6] 6 1
# dealer:  1 playerSum:  6 action:  0 n:  45.0
# stick:  5
# 5445  --  [5, 22] [3, 5] 5 1
# dealer:  5 playerSum:  5 action:  0 n:  38.0
# stick:  15
# 5446  --  [7, -2] [6, 15] 15 1
# dealer:  7 playerSum:  15 action:  0 n:  9.0
# stick:  8
# 5447  --  [2, -1] [8] 8 1
# dealer:  2 playerSum:  8 action:  0 n:  34.0
# stick:  4
# 5448  --  [3, 17] [4] 4 -1
# dealer:  3 playerSum:  4 action:  0 n:  37.0
# stick:  6
# 5449  --  [7, 19] [6] 6 -1
# dealer:  7 playerSum:  6 action:  0 n:  42.0
# 5450  --  [5] [8] -2 -1
# dealer:  5 playerSum:  8 action:  1 n:  44.0
# stick:  5
# 5451  --  [3, -4] [8, 5] 5 1
# dealer:  3 playerSum:  5 action:  0 n:  29.0
# stick:  6
# 5452  --  [2, -5] [6] 6 1
# dealer:  2 playerSum:  6 action:  0 n:  35.0
# stick:  1
# 5453  --  [2, 17] [1] 1 -1
# dealer:  2 playerSum:  1 action:  0 n:  32.0
# stick:  5
# 5454  --  [3, 18] [8, 14, 5] 5 -1
# dealer:  3 playerSum:  5 action:  0 n:  30.0
# stick:  18
# 5455  --  [6, -4] [5, 10, 18] 18 1
# dealer:  6 playerSum:  18 action:  0 n:  8.0
# 5456  --  [4] [3] -1 -1
# dealer:  4 playerSum:  3 action:  1 n:  32.0
# stick:  9
# 5457  --  [10, 19] [9] 9 -1
# dealer:  10 playerSum:  9 action:  0 n:  39.0
# stick:  18
# 5458  --  [1, -4] [8, 18] 18 1
# dealer:  1 playerSum:  18 action:  0 n:  5.0
# stick:  9
# 5459  --  [2, 0] [9] 9 1
# dealer:  2 playerSum:  9 action:  0 n:  40.0
# stick:  17
# stick:  17
# 5460  --  [5, 17, 0] [5, 2, 6, 14, 15, 17, 17] 17 1
# dealer:  5 playerSum:  17 action:  0 n:  4.0
# stick:  2
# 5461  --  [9, -1] [2] 2 1
# dealer:  9 playerSum:  2 action:  0 n:  33.0
# stick:  9
# 5462  --  [8, -3] [3, 13, 9] 9 1
# dealer:  8 playerSum:  9 action:  0 n:  42.0
# stick:  5
# 5463  --  [6, 23] [2, 5] 5 1
# dealer:  6 playerSum:  5 action:  0 n:  36.0
# stick:  7
# 5464  --  [4, -6] [9, 3, 7] 7 1
# dealer:  4 playerSum:  7 action:  0 n:  28.0
# stick:  4
# 5465  --  [3, 18] [4] 4 -1
# dealer:  3 playerSum:  4 action:  0 n:  38.0
# stick:  10
# 5466  --  [3, 18] [2, 9, 6, 10] 10 -1
# dealer:  3 playerSum:  10 action:  0 n:  47.0
# stick:  4
# 5467  --  [4, -5] [4] 4 1
# dealer:  4 playerSum:  4 action:  0 n:  36.0
# stick:  9
# 5468  --  [8, 23] [9] 9 1
# dealer:  8 playerSum:  9 action:  0 n:  43.0
# stick:  11
# 5469  --  [1, -3] [8, 5, 4, 11] 11 1
# dealer:  1 playerSum:  11 action:  0 n:  12.0
# stick:  6
# 5470  --  [7, 17] [6, 10, 6] 6 -1
# dealer:  7 playerSum:  6 action:  0 n:  43.0
# stick:  1
# 5471  --  [4, 21] [1] 1 -1
# dealer:  4 playerSum:  1 action:  0 n:  24.0
# stick:  9
# 5472  --  [2, 23] [2, 9] 9 1
# dealer:  2 playerSum:  9 action:  0 n:  41.0
# 5473  --  [10] [1] -7 -1
# dealer:  10 playerSum:  1 action:  1 n:  26.0
# stick:  7
# 5474  --  [4, -5] [1, 7] 7 1
# dealer:  4 playerSum:  7 action:  0 n:  29.0
# stick:  8
# 5475  --  [1, 0] [4, 8] 8 1
# dealer:  1 playerSum:  8 action:  0 n:  36.0
# stick:  4
# 5476  --  [1, 23] [4] 4 1
# dealer:  1 playerSum:  4 action:  0 n:  33.0
# stick:  3
# 5477  --  [7, 21] [3] 3 -1
# dealer:  7 playerSum:  3 action:  0 n:  44.0
# stick:  13
# 5478  --  [3, 17] [5, 13] 13 -1
# dealer:  3 playerSum:  13 action:  0 n:  21.0
# stick:  1
# 5479  --  [3, 22] [1] 1 1
# dealer:  3 playerSum:  1 action:  0 n:  24.0
# stick:  10
# 5480  --  [2, 20] [10] 10 -1
# dealer:  2 playerSum:  10 action:  0 n:  31.0
# stick:  6
# 5481  --  [8, 20] [1, 6] 6 -1
# dealer:  8 playerSum:  6 action:  0 n:  43.0
# 5482  --  [2] [3] -2 -1
# dealer:  2 playerSum:  3 action:  1 n:  28.0
# stick:  5
# 5483  --  [8, 17] [5] 5 -1
# dealer:  8 playerSum:  5 action:  0 n:  36.0
# stick:  10
# 5484  --  [9, -7] [10] 10 1
# dealer:  9 playerSum:  10 action:  0 n:  33.0
# 5485  --  [8] [4, 9] 0 -1
# dealer:  8 playerSum:  9 action:  1 n:  49.0
# stick:  5
# 5486  --  [2, 24] [5] 5 1
# dealer:  2 playerSum:  5 action:  0 n:  32.0
# stick:  10
# 5487  --  [10, 18] [10] 10 -1
# dealer:  10 playerSum:  10 action:  0 n:  38.0
# stick:  2
# 5488  --  [10, 20] [3, 2] 2 -1
# dealer:  10 playerSum:  2 action:  0 n:  32.0
# stick:  5
# 5489  --  [2, -5] [5] 5 1
# dealer:  2 playerSum:  5 action:  0 n:  33.0
# stick:  7
# 5490  --  [2, 26] [7] 7 1
# dealer:  2 playerSum:  7 action:  0 n:  32.0
# stick:  11
# 5491  --  [6, 19] [6, 11] 11 -1
# dealer:  6 playerSum:  11 action:  0 n:  9.0
# 5492  --  [8] [4] -5 -1
# dealer:  8 playerSum:  4 action:  1 n:  42.0
# stick:  10
# 5493  --  [5, -1] [10] 10 1
# dealer:  5 playerSum:  10 action:  0 n:  43.0
# stick:  12
# 5494  --  [6, 20] [4, 6, 12] 12 -1
# dealer:  6 playerSum:  12 action:  0 n:  14.0
# stick:  6
# 5495  --  [6, 18] [6] 6 -1
# dealer:  6 playerSum:  6 action:  0 n:  39.0
# stick:  1
# 5496  --  [1, -3] [1] 1 1
# dealer:  1 playerSum:  1 action:  0 n:  37.0
# stick:  3
# 5497  --  [3, -5] [1, 3] 3 1
# dealer:  3 playerSum:  3 action:  0 n:  31.0
# stick:  13
# 5498  --  [10, 26] [6, 13] 13 1
# dealer:  10 playerSum:  13 action:  0 n:  16.0
# stick:  18
# 5499  --  [8, 24] [7, 17, 18] 18 1
# dealer:  8 playerSum:  18 action:  0 n:  7.0
# stick:  6
# 5500  --  [2, 19] [6] 6 -1
# dealer:  2 playerSum:  6 action:  0 n:  36.0
# stick:  10
# 5501  --  [2, 0] [10] 10 1
# dealer:  2 playerSum:  10 action:  0 n:  32.0
# stick:  10
# 5502  --  [6, 20] [3, 9, 10] 10 -1
# dealer:  6 playerSum:  10 action:  0 n:  61.0
# 5503  --  [5] [8] -1 -1
# dealer:  5 playerSum:  8 action:  1 n:  45.0
# stick:  3
# 5504  --  [9, -1] [3] 3 1
# dealer:  9 playerSum:  3 action:  0 n:  39.0
# stick:  6
# 5505  --  [4, 24] [6] 6 1
# dealer:  4 playerSum:  6 action:  0 n:  20.0
# stick:  6
# 5506  --  [5, 20] [6] 6 -1
# dealer:  5 playerSum:  6 action:  0 n:  44.0
# stick:  10
# 5507  --  [1, 0] [10] 10 1
# dealer:  1 playerSum:  10 action:  0 n:  44.0
# stick:  2
# 5508  --  [10, 20] [2] 2 -1
# dealer:  10 playerSum:  2 action:  0 n:  33.0
# 5509  --  [3] [9, 17, 20] 21 -1
# dealer:  3 playerSum:  20 action:  1 n:  5.0
# stick:  7
# 5510  --  [3, -2] [7] 7 1
# dealer:  3 playerSum:  7 action:  0 n:  39.0
# stick:  1
# 5511  --  [8, 19] [1] 1 -1
# dealer:  8 playerSum:  1 action:  0 n:  27.0
# stick:  8
# 5512  --  [3, 17] [8] 8 -1
# dealer:  3 playerSum:  8 action:  0 n:  39.0
# stick:  8
# 5513  --  [1, -9] [8] 8 1
# dealer:  1 playerSum:  8 action:  0 n:  37.0
# stick:  3
# 5514  --  [8, 17] [3] 3 -1
# dealer:  8 playerSum:  3 action:  0 n:  37.0
# stick:  9
# 5515  --  [5, -1] [2, 6, 9] 9 1
# dealer:  5 playerSum:  9 action:  0 n:  31.0
# stick:  17
# 5516  --  [1, 0] [10, 6, 9, 16, 17] 17 1
# dealer:  1 playerSum:  17 action:  0 n:  7.0
# stick:  15
# 5517  --  [9, 19] [6, 15] 15 -1
# dealer:  9 playerSum:  15 action:  0 n:  10.0
# stick:  1
# 5518  --  [2, 21] [1] 1 -1
# dealer:  2 playerSum:  1 action:  0 n:  33.0
# stick:  9
# 5519  --  [9, 17] [9] 9 -1
# dealer:  9 playerSum:  9 action:  0 n:  43.0
# stick:  3
# 5520  --  [6, -5] [5, 3] 3 1
# dealer:  6 playerSum:  3 action:  0 n:  34.0
# stick:  19
# 5521  --  [9, -1] [10, 19] 19 1
# dealer:  9 playerSum:  19 action:  0 n:  3.0
# stick:  2
# 5522  --  [1, 19] [2] 2 -1
# dealer:  1 playerSum:  2 action:  0 n:  35.0
# stick:  2
# 5523  --  [1, 0] [2] 2 1
# dealer:  1 playerSum:  2 action:  0 n:  36.0
# stick:  6
# 5524  --  [2, 18] [3, 6] 6 -1
# dealer:  2 playerSum:  6 action:  0 n:  37.0
# stick:  6
# 5525  --  [2, 21] [6] 6 -1
# dealer:  2 playerSum:  6 action:  0 n:  38.0
# stick:  2
# 5526  --  [5, 23] [2] 2 1
# dealer:  5 playerSum:  2 action:  0 n:  21.0
# stick:  6
# 5527  --  [3, -1] [6] 6 1
# dealer:  3 playerSum:  6 action:  0 n:  40.0
# stick:  1
# 5528  --  [2, 23] [1] 1 1
# dealer:  2 playerSum:  1 action:  0 n:  34.0
# stick:  13
# 5529  --  [2, -4] [7, 13] 13 1
# dealer:  2 playerSum:  13 action:  0 n:  14.0
# stick:  5
# 5530  --  [6, 24] [5] 5 1
# dealer:  6 playerSum:  5 action:  0 n:  37.0
# stick:  19
# 5531  --  [3, -1] [5, 12, 19] 19 1
# dealer:  3 playerSum:  19 action:  0 n:  8.0
# stick:  6
# 5532  --  [2, -2] [6] 6 1
# dealer:  2 playerSum:  6 action:  0 n:  39.0
# stick:  7
# 5533  --  [7, 21] [7] 7 -1
# dealer:  7 playerSum:  7 action:  0 n:  31.0
# stick:  5
# 5534  --  [4, -1] [5] 5 1
# dealer:  4 playerSum:  5 action:  0 n:  37.0
# stick:  10
# 5535  --  [9, 17] [10] 10 -1
# dealer:  9 playerSum:  10 action:  0 n:  34.0
# 5536  --  [9] [7, 5] -4 -1
# dealer:  9 playerSum:  5 action:  1 n:  51.0
# stick:  11
# 5537  --  [1, 17] [4, 2, 11] 11 -1
# dealer:  1 playerSum:  11 action:  0 n:  13.0
# stick:  9
# 5538  --  [9, 18] [8, 9] 9 -1
# dealer:  9 playerSum:  9 action:  0 n:  44.0
# stick:  8
# 5539  --  [9, -1] [7, 8] 8 1
# dealer:  9 playerSum:  8 action:  0 n:  33.0
# stick:  5
# 5540  --  [6, 22] [5] 5 1
# dealer:  6 playerSum:  5 action:  0 n:  38.0
# stick:  6
# 5541  --  [9, -1] [5, 6] 6 1
# dealer:  9 playerSum:  6 action:  0 n:  44.0
# stick:  8
# 5542  --  [6, -1] [7, 15, 8] 8 1
# dealer:  6 playerSum:  8 action:  0 n:  33.0
# 5543  --  [9] [2] -6 -1
# dealer:  9 playerSum:  2 action:  1 n:  23.0
# stick:  8
# 5544  --  [10, 18] [7, 8] 8 -1
# dealer:  10 playerSum:  8 action:  0 n:  38.0
# stick:  4
# 5545  --  [8, 21] [3, 12, 4] 4 -1
# dealer:  8 playerSum:  4 action:  0 n:  29.0
# stick:  6
# 5546  --  [4, 17] [6] 6 -1
# dealer:  4 playerSum:  6 action:  0 n:  21.0
# stick:  6
# 5547  --  [9, 19] [6] 6 -1
# dealer:  9 playerSum:  6 action:  0 n:  45.0
# stick:  8
# 5548  --  [3, 23] [8] 8 1
# dealer:  3 playerSum:  8 action:  0 n:  40.0
# stick:  9
# 5549  --  [5, 20] [9] 9 -1
# dealer:  5 playerSum:  9 action:  0 n:  32.0
# stick:  8
# 5550  --  [5, 19] [7, 10, 5, 8] 8 -1
# dealer:  5 playerSum:  8 action:  0 n:  42.0
# stick:  9
# 5551  --  [1, 19] [9] 9 -1
# dealer:  1 playerSum:  9 action:  0 n:  34.0
# stick:  12
# 5552  --  [4, 17] [5, 12] 12 -1
# dealer:  4 playerSum:  12 action:  0 n:  12.0
# stick:  13
# 5553  --  [6, 18] [3, 13] 13 -1
# dealer:  6 playerSum:  13 action:  0 n:  14.0
# stick:  13
# 5554  --  [4, -3] [10, 13] 13 1
# dealer:  4 playerSum:  13 action:  0 n:  10.0
# stick:  2
# 5555  --  [7, -1] [1, 2] 2 1
# dealer:  7 playerSum:  2 action:  0 n:  38.0
# stick:  1
# 5556  --  [2, 18] [1] 1 -1
# dealer:  2 playerSum:  1 action:  0 n:  35.0
# stick:  7
# 5557  --  [4, -1] [7] 7 1
# dealer:  4 playerSum:  7 action:  0 n:  30.0
# 5558  --  [9] [7, 14, 15] 24 -1
# dealer:  9 playerSum:  15 action:  1 n:  12.0
# 5559  --  [7] [1] -5 -1
# dealer:  7 playerSum:  1 action:  1 n:  24.0
# stick:  12
# 5560  --  [10, 18] [8, 12] 12 -1
# dealer:  10 playerSum:  12 action:  0 n:  14.0
# stick:  3
# 5561  --  [6, 17] [3] 3 -1
# dealer:  6 playerSum:  3 action:  0 n:  35.0
# stick:  8
# 5562  --  [7, 18] [10, 8] 8 -1
# dealer:  7 playerSum:  8 action:  0 n:  39.0
# stick:  10
# 5563  --  [5, 20] [5, 10] 10 -1
# dealer:  5 playerSum:  10 action:  0 n:  44.0
# stick:  1
# 5564  --  [9, -3] [1] 1 1
# dealer:  9 playerSum:  1 action:  0 n:  31.0
# stick:  12
# 5565  --  [5, -2] [8, 14, 12] 12 1
# dealer:  5 playerSum:  12 action:  0 n:  7.0
# stick:  1
# 5566  --  [5, 17] [1] 1

# %%
np.set_printoptions(suppress=True)
q

# %%
q.shape

# %%
q[:,:,1]

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

Z = q[:,:,1]

# %%
Z.T.shape

# %%
Z.T

# %%
X = np.arange(21)
Y = np.arange(10)
X,Y = np.meshgrid(X,Y)

# %%
X

# %%
Y

# %%
# use matplotlib 2.0
% matplotlib nbagg
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

Z = q[:,:,1] # Policy for hit. To display policy for stick change 1 to 0
X = np.arange(21)
Y = np.arange(10)
X,Y = np.meshgrid(X,Y)

fig = plt.figure(figsize = (15,10))
ax = fig.gca(projection='3d')

surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

#ax.set_zlim(0, 1)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
# use matplotlib 2.0
% matplotlib nbagg
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

Z = q[:,:,0] # Policy for hit. To display policy for stick change 1 to 0
X = np.arange(21)
Y = np.arange(10)
X,Y = np.meshgrid(X,Y)

fig = plt.figure(figsize = (15,10))
ax = fig.gca(projection='3d')

surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

#ax.set_zlim(0, 1)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %% [markdown]
# # CONCLUSION
#
# From the diagrams above we can observe that the agent has learnt to stick when the player sum is more towards 21 and hit more at the start when it needs to increase the sum towards 21

# %% [markdown]
# ## Let's Play

# %% [markdown]
# Face cards (kings, queens, and jacks) are counted as ten points. A player and the dealer can count an ace as 1 point or 11 points.

# %%
yourSum = 0
playerStop = False
global handNumber
handNumber = 0
# https://www.youtube.com/watch?v=idB-7FUaC-g
# play with my player's recommendation

# %%
def play( playerAction):
    global playerStop
    if playerAction == 1 and playerStop == False:
#         cardColorIndex, cardNumber = deal()
        return deal()
    else:
        playerStop = True
        print "Player stopped"

# %%
cardColorIndex, cardNumber = play(1)

# %%
cardColorIndex , cardNumber

# %%
import json

with open("q.json","w") as f:
    f.write("data = '"+(json.dumps(q.tolist()))+"'")

# %%
import ipywidgets as widgets
from ipywidgets import Button, Layout
from IPython.display import Image

# %%
from IPython.display import Javascript, display_javascript, HTML
from time import sleep

HTML(open("displayCards.html", "r").read())
